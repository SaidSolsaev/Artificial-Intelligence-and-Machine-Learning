# %% [markdown]
# ## IN3050/IN4050 Mandatory Assignment 2, 2023: Supervised Learning

# %% [markdown]
# ### Rules
#
# Before you begin the exercise, review the rules at this website:
#
# - https://www.uio.no/english/studies/examinations/compulsory-activities/mn-ifi-mandatory.html
#
# in particular the paragraph on cooperation. This is an individual assignment. You are not allowed to deliver together or copy/share source-code/answers with others. Read also the "Routines for handling suspicion of cheating and attempted cheating at the University of Oslo":
# - https://www.uio.no/english/studies/examinations/cheating/index.html
#
# By submitting this assignment, you confirm that you are familiar with the rules and the consequences of breaking them.
#
# ### Delivery
#
# **Deadline**: Friday, March 24, 2023, 23:59
#
# Your submission should be delivered in Devilry. You may redeliver in Devilry before the deadline, but include all files in the last delivery, as only the last delivery will be read. You are recommended to upload preliminary versions hours (or days) before the final deadline.
#
# ### What to deliver?
#
# You are recommended to solve the exercise in a Jupyter notebook, but you might solve it in a Python program if you prefer.
#
# #### Alternative 1
# If you choose Jupyter, you should deliver the notebook. You should answer all questions and explain what you are doing in Markdown. Still, the code should be properly commented. The notebook should contain results of your runs. In addition, you should make a pdf of your solution which shows the results of the runs. (If you can't export: notebook -> latex -> pdf on your own machine, you may do this on the IFI linux machines.)
#
# #### Alternative 2
# If you prefer not to use notebooks, you should deliver the code, your run results, and a pdf-report where you answer all the questions and explain your work.
#
# Here is a list of *absolutely necessary* (but not sufficient) conditions to get the assignment marked as passed:
#
# - You must deliver your code (python file or notebook) you used to solve the assignment.
# - The code used for making the output and plots must be included in the assignment.
# - You must include example runs that clearly shows how to run all implemented functions and methods.
# - All the code (in notebook cells or python main-blocks) must run. If you have unfinished code that crashes, please comment it out and document what you think causes it to crash.
# - You must also deliver a pdf of the code, outputs, comments and plots as explained above.
#
# Your report/notebook should contain your name and username.
#
# Deliver one single zipped folder (.zip, .tgz or .tar.gz) which contains your complete solution.
#
# Important: if you weren’t able to finish the assignment, use the PDF report/Markdown to elaborate on what you’ve tried and what problems you encountered. Students who have made an effort and attempted all parts of the assignment will get a second chance even if they fail initially. This exercise will be graded PASS/FAIL.

# %% [markdown]
# ### Goals of the assignment
# The goal of this assignment is to get a better understanding of supervised learning with gradient descent. It will, in particular, consider the similarities and differences between linear classifiers and multi-layer feed forward networks (multi-layer perceptron, MLP) and the differences and similarities between binary and multi-class classification. A main part will be dedicated to implementing and understanding the backpropagation algorithm.
#
# ### Tools
# The aim of the exercises is to give you a look inside the learning algorithms. You may freely use code from the weekly exercises and the published solutions. You should not use ML libraries like scikit-learn or tensorflow.
#
# You may use tools like NumPy and Pandas, which are not specific ML-tools.
#
# The given precode uses NumPy. You are recommended to use NumPy since it results in more compact code, but feel free to use pure python if you prefer.
#
# ### Beware
# There might occur typos or ambiguities. This is a revised assignment compared to earlier years, and there might be new typos. If anything is unclear, do not hesitate to ask. Also, if you think some assumptions are missing, make your own and explain them!

# %% [markdown]
# ### Initialization

# %%
import numpy as np
import matplotlib.pyplot as plt
import sklearn #for datasets

# %% [markdown]
# ## Datasets
#
# We start by making a synthetic dataset of 2000 datapoints and five classes, with 400 individuals in each class. (See https://scikit-learn.org/stable/modules/generated/sklearn.datasets.make_blobs.html regarding how the data are generated.) We choose to use a synthetic dataset---and not a set of natural occuring data---because we are mostly interested in properties of the various learning algorithms, in particular the differences between linear classifiers and multi-layer neural networks together with the difference between binary and multi-class data.
#
# When we are doing experiments in supervised learning, and the data are not already split into training and test sets, we should start by splitting the data. Sometimes there are natural ways to split the data, say training on data from one year and testing on data from a later year, but if that is not the case, we should shuffle the data randomly before splitting. (OK, that is not necessary with this particular synthetic data set, since it is already shuffled by default by scikit, but that will not be the case with real-world data.) We should split the data so that we keep the alignment between X and t, which may be achieved by shuffling the indices. We split into 50% for training, 25% for validation, and 25% for final testing. The set for final testing *must not be used* till the end of the assignment in part 3.
#
# We fix the seed both for data set generation and for shuffling, so that we work on the same datasets when we rerun the experiments. This is done by the `random_state` argument and the `rng = np.random.RandomState(2022)`.

# %%
from sklearn.datasets import make_blobs
X, t_multi = make_blobs(n_samples=[400,400,400, 400, 400], 
                        centers=[[0,1],[4,2],[8,1],[2,0],[6,0]], 
                        cluster_std=[1.0, 2.0, 1.0, 0.5, 0.5],
                        n_features=2, random_state=2022)

# %%
indices = np.arange(X.shape[0])
rng = np.random.RandomState(2022)
rng.shuffle(indices)
indices[:10]
# Out:
# array([1018, 1295,  643, 1842, 1669,   86,  164, 1653, 1174,  747])

# %%
X_train = X[indices[:1000],:]
X_val = X[indices[1000:1500],:]
X_test = X[indices[1500:],:]
t_multi_train = t_multi[indices[:1000]]
t_multi_val = t_multi[indices[1000:1500]]
t_multi_test = t_multi[indices[1500:]]

# %% [markdown]
# Next, we will  make a second dataset by merging classes in (X,t) into two classes and call the new set (X, t2). This will be a binary set.
# We now have two datasets:
#
# - Binary set: `(X, t2)`
# - Multi-class set: `(X, t_multi)`

# %%
t2_train = t_multi_train >= 3
t2_train = t2_train.astype('int')
t2_val = (t_multi_val >= 3).astype('int')
t2_test = (t_multi_test >= 3).astype('int')

# %% [markdown]
# We can plot the two traning sets.

# %%
plt.figure(figsize=(8,6)) # You may adjust the size
plt.scatter(X_train[:, 0], X_train[:, 1], c=t_multi_train, s=10.0)
plt.title('Multi-class set')
# Out:
# Text(0.5, 1.0, 'Multi-class set')

# %%
plt.figure(figsize=(8,6))
plt.scatter(X_train[:, 0], X_train[:, 1], c=t2_train, s=10.0)
plt.title('Binary set')
# Out:
# Text(0.5, 1.0, 'Binary set')

# %% [markdown]
# # Part I: Linear classifiers
# ## Linear regression

# %% [markdown]
# We see that that set (X, t2) is far from linearly separable, and we will explore how various classifiers are able to handle this. We start with linear regression. You may make your own implementation from scratch or start with the solution to the weekly exercise set 7.
# We include it here with a little added flexibility.

# %%
def add_bias(X, bias):
    """X is a Nxm matrix: N datapoints, m features
    bias is a bias term, -1 or 1. Use 0 for no bias
    Return a Nx(m+1) matrix with added bias in position zero
    """
    N = X.shape[0]
    biases = np.ones((N, 1))*bias # Make a N*1 matrix of bias-s
    # Concatenate the column of biases in front of the columns of X.
    return np.concatenate((biases, X), axis  = 1)

# %%
class NumpyClassifier():
    """Common methods to all numpy classifiers --- if any"""

# %%
class NumpyLinRegClass(NumpyClassifier):

    def __init__(self, bias=-1):
        self.bias=bias
    
    def fit(self, X_train, t_train, eta = 0.1, epochs=10):
        """X_train is a Nxm matrix, N data points, m features
        t_train is avector of length N,
        the targets values for the training data"""
        
        if self.bias:
            X_train = add_bias(X_train, self.bias)
            
        (N, m) = X_train.shape
        
        self.weights = weights = np.zeros(m)
        
        for e in range(epochs):
            weights -= eta / N *  X_train.T @ (X_train @ weights - t_train)      
    
    def predict(self, X, threshold=0.5):
        """X is a Kxm matrix for some K>=1
        predict the value for each point in X"""
        if self.bias:
            X = add_bias(X, self.bias)
        ys = X @ self.weights
        return ys > threshold

# %% [markdown]
# We can train and test a first classifier.

# %%
def accuracy(predicted, gold):
    return np.mean(predicted == gold)

# %%
cl = NumpyLinRegClass()
cl.fit(X_train, t2_train)
accuracy(cl.predict(X_val), t2_val)
# Out:
# 0.522

# %% [markdown]
# The following is a small procedure which plots the data set together with the decision boundaries.
# You may modify the colors and the rest of the graphics as you like.
# The procedure will also work for multi-class classifiers

# %%
def plot_decision_regions(X, t, clf=[], size=(8,6)):
    """Plot the data set (X,t) together with the decision boundary of the classifier clf"""
    # The region of the plane to consider determined by X
    x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    
    # Make a make of the whole region
    h = 0.02  # step size in the mesh
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
    # Classify each meshpoint.
    Z = Z.reshape(xx.shape)

    plt.figure(figsize=size) # You may adjust this

    # Put the result into a color plot
    plt.contourf(xx, yy, Z, alpha=0.2, cmap = 'Paired')

    plt.scatter(X[:,0], X[:,1], c=t, s=10.0, cmap='Paired')

    plt.xlim(xx.min(), xx.max())
    plt.ylim(yy.min(), yy.max())
    plt.title("Decision regions")
    plt.xlabel("x0")
    plt.ylabel("x1")

#    plt.show()

# %%
plot_decision_regions(X_train, t2_train, cl)

# %% [markdown]
# ### Task: Tuning
#
# The result is far from impressive.
# Remember that a classifier which always chooses the majority class will have an accuracy of 0.6 on this data set.
#
# Your task is to try various settings for the two training hyper-parameters, *eta* and *epochs*, to get the best accuracy on the validation set.
#
# Report how the accuracy vary with the hyper-parameter settings. It it not sufficient to give the final hyperparemters. You must also show how you found them  and results for alternative values you tried aout.
#
# When you are satisfied with the result, you may plot the decision boundaries, as above.

# %%
clf = NumpyLinRegClass()

# Define hyperparameters to try
etas = [0.001, 0.01, 0.1, 1]
epochs = [10, 50, 100, 500, 1000]

#Lete etter det som gir best accuracy, prøve forskjellige eta og epochs
best_accuracy = 0
best_params = {}
for eta in etas:
    for epoch in epochs:
        clf.fit(X_train, t2_train, eta=eta, epochs=epoch)
        predictions = clf.predict(X_val)
        accuracy = np.mean(predictions == t2_val)
        print(f"eta={eta}, epochs={epoch}, accuracy={accuracy}")
        if accuracy > best_accuracy:
            best_accuracy = accuracy
            best_params = {'eta': eta, 'epochs': epoch}

print(f"Best hyperparameters: {best_params}, accuracy: {best_accuracy}")

clf.fit(X_train, t2_train, eta=best_params['eta'], epochs=best_params['epochs'])
plot_decision_regions(X_train, t2_train, clf)
# Out:
# eta=0.001, epochs=10, accuracy=0.576
# eta=0.001, epochs=50, accuracy=0.576
# eta=0.001, epochs=100, accuracy=0.522
# eta=0.001, epochs=500, accuracy=0.504
# eta=0.001, epochs=1000, accuracy=0.56
# eta=0.01, epochs=10, accuracy=0.502
# eta=0.01, epochs=50, accuracy=0.504
# eta=0.01, epochs=100, accuracy=0.56
# eta=0.01, epochs=500, accuracy=0.658
# eta=0.01, epochs=1000, accuracy=0.686
# eta=0.1, epochs=10, accuracy=0.522
# eta=0.1, epochs=50, accuracy=0.516
# eta=0.1, epochs=100, accuracy=0.516
# eta=0.1, epochs=500, accuracy=0.516
# eta=0.1, epochs=1000, accuracy=0.516
# eta=1, epochs=10, accuracy=0.516
# eta=1, epochs=50, accuracy=0.516
# eta=1, epochs=100, accuracy=0.516
# eta=1, epochs=500, accuracy=0.576
# eta=1, epochs=1000, accuracy=0.576
# Best hyperparameters: {'eta': 0.01, 'epochs': 1000}, accuracy: 0.686
# C:\Users\Said Solsaev\AppData\Local\Temp\ipykernel_6292\1306046024.py:19: RuntimeWarning: overflow encountered in matmul
#   weights -= eta / N *  X_train.T @ (X_train @ weights - t_train)
# C:\Users\Said Solsaev\AppData\Local\Temp\ipykernel_6292\1306046024.py:19: RuntimeWarning: invalid value encountered in matmul
#   weights -= eta / N *  X_train.T @ (X_train @ weights - t_train)

# %% [markdown]
# ### Task: Loss
# The linear regression classifier is trained with mean squared error loss. So far, we have not calculated the loss explicitly in the code. Extend the code to calculate the loss on the training set for each epoch and to store the losses such that the losses can be inspected after training.
#
# Also extend the classifier to calculate the accuracy on the training data after each epoch.
#
# Train a classifier with your best settings from last point. After training, plot the loss as a function of the number of epochs. Then plot the accuracy as a function of the number of epochs.
#
# Comment on what you see: Are the function monotone? Is this as expected?

# %%
import matplotlib.pyplot as plt

def accuracy(predicted, gold):
    return np.mean(predicted == gold)

class NumpyLinRegClass(NumpyClassifier):

    def __init__(self, bias=-1):
        self.bias=bias
    
    def fit(self, X_train, t_train, eta = 0.1, epochs=10):
        """X_train is a Nxm matrix, N data points, m features
        t_train is avector of length N,
        the targets values for the training data"""
        
        if self.bias:
            X_train = add_bias(X_train, self.bias)
            
        (N, m) = X_train.shape
        
        self.weights = weights = np.zeros(m)
        self.nøyaktighetListe = [] #Liste over nøyaktigheten for epochs
        self.tap = [] #Liste over alle tap for epochs
        
        for e in range(epochs):
            ys = X_train @ weights
            tap = ((ys - t_train) **2).mean() #Kalkuler hvert tap
            train_accuracy = accuracy((ys > 0.5).astype(int), t_train) #Kalkuler nøyaktigheten
            weights -= eta / N *  X_train.T @ (ys - t_train)      

            self.nøyaktighetListe.append(train_accuracy) #legger til nøyaktighetene lista
            self.tap.append(tap) #Legger til tapene i lista
            print(f"Epochs: {e}: Nøyaktighet:{train_accuracy} | Tap:{tap}") #printer ut for hver epoch
    
    def predict(self, X, threshold=0.5):
        """X is a Kxm matrix for some K>=1
        predict the value for each point in X"""
        if self.bias:
            X = add_bias(X, self.bias)
        ys = X @ self.weights
        return ys > threshold
    

def plot_losses(cl):
    mean = np.mean(X_train, axis=0)
    std = np.std(X_train, axis=0)
    dataNorm = (X_train - mean) / std #Normailiserer data vi får

    cl.fit(dataNorm, t2_train, eta=0.01, epochs=1000) #kaller på fit med de beste eta og epochs jeg fant fra forrige oppg
    
    
    
    plt.plot(cl.nøyaktighetListe)
    plt.xlabel('epoches')
    plt.title('accuracy')
    plt.show()

    plt.plot(cl.tap)
    plt.xlabel('epoches')
    plt.title('lossess')
    plt.show()
    plot_decision_regions(dataNorm, t2_train, cl)

clf = NumpyLinRegClass()
plot_losses(clf)
plt.show()
# Out:
# Epochs: 0: Nøyaktighet:0.614 | Tap:0.386
# Epochs: 1: Nøyaktighet:0.614 | Tap:0.381919364931528
# Epochs: 2: Nøyaktighet:0.614 | Tap:0.3779199038606057
# Epochs: 3: Nøyaktighet:0.614 | Tap:0.3740000019847451
# Epochs: 4: Nøyaktighet:0.614 | Tap:0.3701580766258693
# Epochs: 5: Nøyaktighet:0.614 | Tap:0.3663925765912196
# Epochs: 6: Nøyaktighet:0.614 | Tap:0.3627019815469774
# Epochs: 7: Nøyaktighet:0.614 | Tap:0.35908480140434673
# Epochs: 8: Nøyaktighet:0.614 | Tap:0.3555395757178514
# Epochs: 9: Nøyaktighet:0.614 | Tap:0.35206487309560314
# Epochs: 10: Nøyaktighet:0.614 | Tap:0.34865929062130196
# Epochs: 11: Nøyaktighet:0.614 | Tap:0.3453214532877356
# Epochs: 12: Nøyaktighet:0.614 | Tap:0.34205001344154984
# Epochs: 13: Nøyaktighet:0.614 | Tap:0.33884365023906493
# Epochs: 14: Nøyaktighet:0.614 | Tap:0.3357010691129182
# Epochs: 15: Nøyaktighet:0.614 | Tap:0.33262100124931815
# Epochs: 16: Nøyaktighet:0.614 | Tap:0.32960220307569776
# Epochs: 17: Nøyaktighet:0.614 | Tap:0.3266434557585618
# Epochs: 18: Nøyaktighet:0.614 | Tap:0.3237435647113235
# Epochs: 19: Nøyaktighet:0.614 | Tap:0.32090135911193307
# Epochs: 20: Nøyaktighet:0.614 | Tap:0.318115691430103
# Epochs: 21: Nøyaktighet:0.614 | Tap:0.3153854369639388
# Epochs: 22: Nøyaktighet:0.614 | Tap:0.31270949338578846
# Epochs: 23: Nøyaktighet:0.614 | Tap:0.3100867802971273
# Epochs: 24: Nøyaktighet:0.614 | Tap:0.3075162387922977
# Epochs: 25: Nøyaktighet:0.614 | Tap:0.304996831030929
# Epochs: 26: Nøyaktighet:0.614 | Tap:0.302527539818863
# Epochs: 27: Nøyaktighet:0.614 | Tap:0.3001073681974175
# Epochs: 28: Nøyaktighet:0.614 | Tap:0.2977353390408208
# Epochs: 29: Nøyaktighet:0.614 | Tap:0.29541049466165586
# Epochs: 30: Nøyaktighet:0.614 | Tap:0.2931318964241529
# Epochs: 31: Nøyaktighet:0.614 | Tap:0.29089862436517616
# Epochs: 32: Nøyaktighet:0.614 | Tap:0.2887097768227511
# Epochs: 33: Nøyaktighet:0.614 | Tap:0.28656447007198116
# Epochs: 34: Nøyaktighet:0.614 | Tap:0.2844618379682087
# Epochs: 35: Nøyaktighet:0.614 | Tap:0.28240103159727425
# Epochs: 36: Nøyaktighet:0.614 | Tap:0.2803812189327343
# Epochs: 37: Nøyaktighet:0.614 | Tap:0.2784015844998984
# Epochs: 38: Nøyaktighet:0.614 | Tap:0.27646132904654996
# Epochs: 39: Nøyaktighet:0.614 | Tap:0.27455966922021807
# Epochs: 40: Nøyaktighet:0.614 | Tap:0.27269583725186985
# Epochs: 41: Nøyaktighet:0.614 | Tap:0.2708690806458952
# Epochs: 42: Nøyaktighet:0.614 | Tap:0.2690786618762599
# Epochs: 43: Nøyaktighet:0.614 | Tap:0.26732385808870274
# Epochs: 44: Nøyaktighet:0.614 | Tap:0.2656039608088579
# Epochs: 45: Nøyaktighet:0.614 | Tap:0.2639182756561838
# Epochs: 46: Nøyaktighet:0.614 | Tap:0.26226612206358313
# Epochs: 47: Nøyaktighet:0.614 | Tap:0.26064683300260094
# Epochs: 48: Nøyaktighet:0.614 | Tap:0.25905975471409
# Epochs: 49: Nøyaktighet:0.613 | Tap:0.2575042464442339
# Epochs: 50: Nøyaktighet:0.613 | Tap:0.25597968018582234
# Epochs: 51: Nøyaktighet:0.613 | Tap:0.2544854404246732
# Epochs: 52: Nøyaktighet:0.613 | Tap:0.25302092389109937
# Epochs: 53: Nøyaktighet:0.613 | Tap:0.25158553931632044
# Epochs: 54: Nøyaktighet:0.613 | Tap:0.25017870719372
# Epochs: 55: Nøyaktighet:0.613 | Tap:0.24879985954485243
# Epochs: 56: Nøyaktighet:0.613 | Tap:0.24744843969010552
# Epochs: 57: Nøyaktighet:0.613 | Tap:0.24612390202392476
# Epochs: 58: Nøyaktighet:0.613 | Tap:0.24482571179450985
# Epochs: 59: Nøyaktighet:0.613 | Tap:0.24355334488789407
# Epochs: 60: Nøyaktighet:0.613 | Tap:0.24230628761631887
# Epochs: 61: Nøyaktighet:0.613 | Tap:0.24108403651081883
# Epochs: 62: Nøyaktighet:0.613 | Tap:0.239886098117933
# Epochs: 63: Nøyaktighet:0.613 | Tap:0.23871198880046032
# Epochs: 64: Nøyaktighet:0.613 | Tap:0.23756123454217917
# Epochs: 65: Nøyaktighet:0.613 | Tap:0.23643337075645146
# Epochs: 66: Nøyaktighet:0.613 | Tap:0.23532794209863475
# Epochs: 67: Nøyaktighet:0.613 | Tap:0.23424450228222604
# Epochs: 68: Nøyaktighet:0.613 | Tap:0.2331826138986635
# Epochs: 69: Nøyaktighet:0.612 | Tap:0.2321418482407125
# Epochs: 70: Nøyaktighet:0.611 | Tap:0.23112178512936601
# Epochs: 71: Nøyaktighet:0.61 | Tap:0.23012201274418823
# Epochs: 72: Nøyaktighet:0.61 | Tap:0.22914212745703322
# Epochs: 73: Nøyaktighet:0.61 | Tap:0.228181733669072
# Epochs: 74: Nøyaktighet:0.61 | Tap:0.2272404436510614
# Epochs: 75: Nøyaktighet:0.61 | Tap:0.22631787738679104
# Epochs: 76: Nøyaktighet:0.609 | Tap:0.22541366241964433
# Epochs: 77: Nøyaktighet:0.609 | Tap:0.2245274337022125
# Epochs: 78: Nøyaktighet:0.609 | Tap:0.22365883344889984
# Epochs: 79: Nøyaktighet:0.609 | Tap:0.2228075109914618
# Epochs: 80: Nøyaktighet:0.609 | Tap:0.2219731226374165
# Epochs: 81: Nøyaktighet:0.609 | Tap:0.22115533153127354
# Epochs: 82: Nøyaktighet:0.609 | Tap:0.2203538075185228
# Epochs: 83: Nøyaktighet:0.609 | Tap:0.2195682270123299
# Epochs: 84: Nøyaktighet:0.609 | Tap:0.2187982728628828
# Epochs: 85: Nøyaktighet:0.609 | Tap:0.21804363422933834
# Epochs: 86: Nøyaktighet:0.609 | Tap:0.21730400645431563
# Epochs: 87: Nøyaktighet:0.609 | Tap:0.21657909094088665
# Epochs: 88: Nøyaktighet:0.609 | Tap:0.21586859503201408
# Epochs: 89: Nøyaktighet:0.609 | Tap:0.21517223189238702
# Epochs: 90: Nøyaktighet:0.609 | Tap:0.21448972039260808
# Epochs: 91: Nøyaktighet:0.609 | Tap:0.21382078499568413
# Epochs: 92: Nøyaktighet:0.609 | Tap:0.2131651556457753
# Epochs: 93: Nøyaktighet:0.609 | Tap:0.21252256765915695
# Epochs: 94: Nøyaktighet:0.608 | Tap:0.21189276161735124
# Epochs: 95: Nøyaktighet:0.608 | Tap:0.21127548326238424
# Epochs: 96: Nøyaktighet:0.605 | Tap:0.2106704833941273
# Epochs: 97: Nøyaktighet:0.605 | Tap:0.21007751776968026
# Epochs: 98: Nøyaktighet:0.605 | Tap:0.2094963470047564
# Epochs: 99: Nøyaktighet:0.605 | Tap:0.20892673647702942
# Epochs: 100: Nøyaktighet:0.604 | Tap:0.20836845623140293
# Epochs: 101: Nøyaktighet:0.604 | Tap:0.20782128088716492
# Epochs: 102: Nøyaktighet:0.604 | Tap:0.20728498954698862
# Epochs: 103: Nøyaktighet:0.604 | Tap:0.20675936570774422
# Epochs: 104: Nøyaktighet:0.603 | Tap:0.20624419717308468
# Epochs: 105: Nøyaktighet:0.603 | Tap:0.2057392759677705
# Epochs: 106: Nøyaktighet:0.603 | Tap:0.20524439825369914
# Epochs: 107: Nøyaktighet:0.604 | Tap:0.2047593642476043
# Epochs: 108: Nøyaktighet:0.604 | Tap:0.20428397814039329
# Epochs: 109: Nøyaktighet:0.603 | Tap:0.20381804801808837
# Epochs: 110: Nøyaktighet:0.603 | Tap:0.2033613857843414
# Epochs: 111: Nøyaktighet:0.605 | Tap:0.2029138070844895
# Epochs: 112: Nøyaktighet:0.607 | Tap:0.20247513123112174
# Epochs: 113: Nøyaktighet:0.606 | Tap:0.20204518113112677
# Epochs: 114: Nøyaktighet:0.605 | Tap:0.20162378321419117
# Epochs: 115: Nøyaktighet:0.604 | Tap:0.20121076736272095
# Epochs: 116: Nøyaktighet:0.604 | Tap:0.20080596684315638
# Epochs: 117: Nøyaktighet:0.604 | Tap:0.20040921823865407
# Epochs: 118: Nøyaktighet:0.604 | Tap:0.2000203613831074
# Epochs: 119: Nøyaktighet:0.605 | Tap:0.19963923929648023
# Epochs: 120: Nøyaktighet:0.604 | Tap:0.19926569812142633
# Epochs: 121: Nøyaktighet:0.602 | Tap:0.19889958706117059
# Epochs: 122: Nøyaktighet:0.602 | Tap:0.19854075831862494
# Epochs: 123: Nøyaktighet:0.602 | Tap:0.19818906703671638
# Epochs: 124: Nøyaktighet:0.601 | Tap:0.19784437123990153
# Epochs: 125: Nøyaktighet:0.605 | Tap:0.1975065317768449
# Epochs: 126: Nøyaktighet:0.607 | Tap:0.19717541226423735
# Epochs: 127: Nøyaktighet:0.606 | Tap:0.1968508790317323
# Epochs: 128: Nøyaktighet:0.606 | Tap:0.19653280106797746
# Epochs: 129: Nøyaktighet:0.608 | Tap:0.1962210499677197
# Epochs: 130: Nøyaktighet:0.608 | Tap:0.19591549987996285
# Epochs: 131: Nøyaktighet:0.609 | Tap:0.19561602745715623
# Epochs: 132: Nøyaktighet:0.609 | Tap:0.19532251180539442
# Epochs: 133: Nøyaktighet:0.609 | Tap:0.1950348344356074
# Epochs: 134: Nøyaktighet:0.611 | Tap:0.19475287921572193
# Epochs: 135: Nøyaktighet:0.612 | Tap:0.19447653232377435
# Epochs: 136: Nøyaktighet:0.611 | Tap:0.1942056822019564
# Epochs: 137: Nøyaktighet:0.611 | Tap:0.19394021951157508
# Epochs: 138: Nøyaktighet:0.612 | Tap:0.19368003708890852
# Epochs: 139: Nøyaktighet:0.612 | Tap:0.1934250299019398
# Epochs: 140: Nøyaktighet:0.611 | Tap:0.19317509500795196
# Epochs: 141: Nøyaktighet:0.611 | Tap:0.19293013151196622
# Epochs: 142: Nøyaktighet:0.615 | Tap:0.1926900405260071
# Epochs: 143: Nøyaktighet:0.618 | Tap:0.19245472512917777
# Epochs: 144: Nøyaktighet:0.618 | Tap:0.19222409032852988
# Epochs: 145: Nøyaktighet:0.619 | Tap:0.1919980430207117
# Epochs: 146: Nøyaktighet:0.618 | Tap:0.19177649195437896
# Epochs: 147: Nøyaktighet:0.617 | Tap:0.19155934769335398
# Epochs: 148: Nøyaktighet:0.619 | Tap:0.19134652258051704
# Epochs: 149: Nøyaktighet:0.621 | Tap:0.1911379307024167
# Epochs: 150: Nøyaktighet:0.621 | Tap:0.1909334878545837
# Epochs: 151: Nøyaktighet:0.622 | Tap:0.19073311150753494
# Epochs: 152: Nøyaktighet:0.625 | Tap:0.190536720773454
# Epochs: 153: Nøyaktighet:0.628 | Tap:0.190344236373534
# Epochs: 154: Nøyaktighet:0.627 | Tap:0.19015558060597085
# Epochs: 155: Nøyaktighet:0.628 | Tap:0.18997067731459238
# Epochs: 156: Nøyaktighet:0.63 | Tap:0.18978945185811216
# Epochs: 157: Nøyaktighet:0.629 | Tap:0.18961183107999457
# Epochs: 158: Nøyaktighet:0.63 | Tap:0.18943774327891963
# Epochs: 159: Nøyaktighet:0.632 | Tap:0.1892671181798353
# Epochs: 160: Nøyaktighet:0.633 | Tap:0.18909988690558532
# Epochs: 161: Nøyaktighet:0.635 | Tap:0.18893598194910197
# Epochs: 162: Nøyaktighet:0.637 | Tap:0.1887753371461517
# Epochs: 163: Nøyaktighet:0.638 | Tap:0.18861788764862286
# Epochs: 164: Nøyaktighet:0.638 | Tap:0.18846356989834512
# Epochs: 165: Nøyaktighet:0.64 | Tap:0.1883123216014294
# Epochs: 166: Nøyaktighet:0.639 | Tap:0.18816408170311832
# Epochs: 167: Nøyaktighet:0.638 | Tap:0.18801879036313718
# Epochs: 168: Nøyaktighet:0.641 | Tap:0.187876388931535
# Epochs: 169: Nøyaktighet:0.641 | Tap:0.18773681992500613
# Epochs: 170: Nøyaktighet:0.641 | Tap:0.18760002700368333
# Epochs: 171: Nøyaktighet:0.644 | Tap:0.1874659549483918
# Epochs: 172: Nøyaktighet:0.644 | Tap:0.1873345496383564
# Epochs: 173: Nøyaktighet:0.646 | Tap:0.18720575802935194
# Epochs: 174: Nøyaktighet:0.649 | Tap:0.18707952813228798
# Epochs: 175: Nøyaktighet:0.649 | Tap:0.18695580899222017
# Epochs: 176: Nøyaktighet:0.649 | Tap:0.18683455066777868
# Epochs: 177: Nøyaktighet:0.649 | Tap:0.18671570421100592
# Epochs: 178: Nøyaktighet:0.651 | Tap:0.18659922164759546
# Epochs: 179: Nøyaktighet:0.655 | Tap:0.18648505595752402
# Epochs: 180: Nøyaktighet:0.654 | Tap:0.1863731610560687
# Epochs: 181: Nøyaktighet:0.656 | Tap:0.18626349177520182
# Epochs: 182: Nøyaktighet:0.657 | Tap:0.18615600384535594
# Epochs: 183: Nøyaktighet:0.656 | Tap:0.18605065387755154
# Epochs: 184: Nøyaktighet:0.658 | Tap:0.18594739934588037
# Epochs: 185: Nøyaktighet:0.658 | Tap:0.185846198570337
# Epochs: 186: Nøyaktighet:0.66 | Tap:0.18574701069999222
# Epochs: 187: Nøyaktighet:0.659 | Tap:0.18564979569650086
# Epochs: 188: Nøyaktighet:0.659 | Tap:0.1855545143179379
# Epochs: 189: Nøyaktighet:0.66 | Tap:0.18546112810295604
# Epochs: 190: Nøyaktighet:0.659 | Tap:0.18536959935525835
# Epochs: 191: Nøyaktighet:0.661 | Tap:0.18527989112837998
# Epochs: 192: Nøyaktighet:0.663 | Tap:0.18519196721077247
# Epochs: 193: Nøyaktighet:0.665 | Tap:0.18510579211118472
# Epochs: 194: Nøyaktighet:0.668 | Tap:0.1850213310443349
# Epochs: 195: Nøyaktighet:0.67 | Tap:0.18493854991686737
# Epochs: 196: Nøyaktighet:0.669 | Tap:0.18485741531358887
# Epochs: 197: Nøyaktighet:0.671 | Tap:0.18477789448397855
# Epochs: 198: Nøyaktighet:0.672 | Tap:0.18469995532896627
# Epochs: 199: Nøyaktighet:0.673 | Tap:0.18462356638797425
# Epochs: 200: Nøyaktighet:0.673 | Tap:0.1845486968262159
# Epochs: 201: Nøyaktighet:0.675 | Tap:0.18447531642224796
# Epochs: 202: Nøyaktighet:0.677 | Tap:0.18440339555576968
# Epochs: 203: Nøyaktighet:0.675 | Tap:0.1843329051956652
# Epochs: 204: Nøyaktighet:0.678 | Tap:0.1842638168882834
# Epochs: 205: Nøyaktighet:0.679 | Tap:0.1841961027459511
# Epochs: 206: Nøyaktighet:0.679 | Tap:0.18412973543571476
# Epochs: 207: Nøyaktighet:0.681 | Tap:0.18406468816830615
# Epochs: 208: Nøyaktighet:0.683 | Tap:0.18400093468732728
# Epochs: 209: Nøyaktighet:0.684 | Tap:0.18393844925865088
# Epochs: 210: Nøyaktighet:0.685 | Tap:0.18387720666003127
# Epochs: 211: Nøyaktighet:0.686 | Tap:0.1838171821709223
# Epochs: 212: Nøyaktighet:0.685 | Tap:0.18375835156249767
# Epochs: 213: Nøyaktighet:0.685 | Tap:0.18370069108786963
# Epochs: 214: Nøyaktighet:0.685 | Tap:0.18364417747250245
# Epochs: 215: Nøyaktighet:0.684 | Tap:0.18358878790481656
# Epochs: 216: Nøyaktighet:0.686 | Tap:0.18353450002697963
# Epochs: 217: Nøyaktighet:0.687 | Tap:0.1834812919258805
# Epochs: 218: Nøyaktighet:0.688 | Tap:0.1834291421242832
# Epochs: 219: Nøyaktighet:0.689 | Tap:0.18337802957215654
# Epochs: 220: Nøyaktighet:0.69 | Tap:0.18332793363817632
# Epochs: 221: Nøyaktighet:0.693 | Tap:0.1832788341013966
# Epochs: 222: Nøyaktighet:0.693 | Tap:0.1832307111430865
# Epochs: 223: Nøyaktighet:0.694 | Tap:0.18318354533872955
# Epochs: 224: Nøyaktighet:0.694 | Tap:0.18313731765018212
# Epochs: 225: Nøyaktighet:0.694 | Tap:0.18309200941798803
# Epochs: 226: Nøyaktighet:0.694 | Tap:0.18304760235384537
# Epochs: 227: Nøyaktighet:0.695 | Tap:0.18300407853322426
# Epochs: 228: Nøyaktighet:0.695 | Tap:0.18296142038813043
# Epochs: 229: Nøyaktighet:0.696 | Tap:0.18291961070001325
# Epochs: 230: Nøyaktighet:0.697 | Tap:0.18287863259281506
# Epochs: 231: Nøyaktighet:0.697 | Tap:0.18283846952615793
# Epochs: 232: Nøyaktighet:0.7 | Tap:0.18279910528866697
# Epochs: 233: Nøyaktighet:0.703 | Tap:0.18276052399142564
# Epochs: 234: Nøyaktighet:0.705 | Tap:0.18272271006156188
# Epochs: 235: Nøyaktighet:0.707 | Tap:0.1826856482359612
# Epochs: 236: Nøyaktighet:0.709 | Tap:0.1826493235551053
# Epochs: 237: Nøyaktighet:0.709 | Tap:0.18261372135703316
# Epochs: 238: Nøyaktighet:0.708 | Tap:0.18257882727142208
# Epochs: 239: Nøyaktighet:0.708 | Tap:0.18254462721378667
# Epochs: 240: Nøyaktighet:0.709 | Tap:0.18251110737979306
# Epochs: 241: Nøyaktighet:0.708 | Tap:0.18247825423968636
# Epochs: 242: Nøyaktighet:0.708 | Tap:0.18244605453282886
# Epochs: 243: Nøyaktighet:0.707 | Tap:0.18241449526234693
# Epochs: 244: Nøyaktighet:0.707 | Tap:0.1823835636898845
# Epochs: 245: Nøyaktighet:0.707 | Tap:0.18235324733046054
# Epochs: 246: Nøyaktighet:0.707 | Tap:0.18232353394742928
# Epochs: 247: Nøyaktighet:0.708 | Tap:0.18229441154754064
# Epochs: 248: Nøyaktighet:0.708 | Tap:0.18226586837609834
# Epochs: 249: Nøyaktighet:0.705 | Tap:0.1822378929122152
# Epochs: 250: Nøyaktighet:0.706 | Tap:0.182210473864162
# Epochs: 251: Nøyaktighet:0.708 | Tap:0.18218360016480956
# Epochs: 252: Nøyaktighet:0.709 | Tap:0.18215726096716095
# Epochs: 253: Nøyaktighet:0.709 | Tap:0.1821314456399728
# Epochs: 254: Nøyaktighet:0.709 | Tap:0.18210614376346393
# Epochs: 255: Nøyaktighet:0.709 | Tap:0.18208134512510873
# Epochs: 256: Nøyaktighet:0.71 | Tap:0.18205703971551482
# Epochs: 257: Nøyaktighet:0.71 | Tap:0.1820332177243825
# Epochs: 258: Nøyaktighet:0.712 | Tap:0.1820098695365445
# Epochs: 259: Nøyaktighet:0.711 | Tap:0.18198698572808455
# Epochs: 260: Nøyaktighet:0.711 | Tap:0.18196455706253326
# Epochs: 261: Nøyaktighet:0.712 | Tap:0.18194257448713944
# Epochs: 262: Nøyaktighet:0.712 | Tap:0.18192102912921587
# Epochs: 263: Nøyaktighet:0.714 | Tap:0.18189991229255761
# Epochs: 264: Nøyaktighet:0.714 | Tap:0.1818792154539315
# Epochs: 265: Nøyaktighet:0.715 | Tap:0.1818589302596355
# Epochs: 266: Nøyaktighet:0.716 | Tap:0.18183904852212687
# Epochs: 267: Nøyaktighet:0.716 | Tap:0.18181956221671655
# Epochs: 268: Nøyaktighet:0.715 | Tap:0.18180046347833037
# Epochs: 269: Nøyaktighet:0.715 | Tap:0.18178174459833368
# Epochs: 270: Nøyaktighet:0.716 | Tap:0.18176339802142
# Epochs: 271: Nøyaktighet:0.715 | Tap:0.1817454163425608
# Epochs: 272: Nøyaktighet:0.715 | Tap:0.1817277923040167
# Epochs: 273: Nøyaktighet:0.716 | Tap:0.1817105187924073
# Epochs: 274: Nøyaktighet:0.716 | Tap:0.18169358883584016
# Epochs: 275: Nøyaktighet:0.718 | Tap:0.18167699560109624
# Epochs: 276: Nøyaktighet:0.719 | Tap:0.18166073239087144
# Epochs: 277: Nøyaktighet:0.72 | Tap:0.1816447926410735
# Epochs: 278: Nøyaktighet:0.72 | Tap:0.18162916991817196
# Epochs: 279: Nøyaktighet:0.719 | Tap:0.1816138579166012
# Epochs: 280: Nøyaktighet:0.72 | Tap:0.1815988504562153
# Epochs: 281: Nøyaktighet:0.72 | Tap:0.1815841414797931
# Epochs: 282: Nøyaktighet:0.721 | Tap:0.18156972505059327
# Epochs: 283: Nøyaktighet:0.721 | Tap:0.18155559534995777
# Epochs: 284: Nøyaktighet:0.721 | Tap:0.18154174667496312
# Epochs: 285: Nøyaktighet:0.722 | Tap:0.18152817343611838
# Epochs: 286: Nøyaktighet:0.723 | Tap:0.18151487015510867
# Epochs: 287: Nøyaktighet:0.722 | Tap:0.18150183146258417
# Epochs: 288: Nøyaktighet:0.722 | Tap:0.18148905209599223
# Epochs: 289: Nøyaktighet:0.723 | Tap:0.18147652689745356
# Epochs: 290: Nøyaktighet:0.723 | Tap:0.1814642508116799
# Epochs: 291: Nøyaktighet:0.723 | Tap:0.18145221888393348
# Epochs: 292: Nøyaktighet:0.723 | Tap:0.18144042625802698
# Epochs: 293: Nøyaktighet:0.723 | Tap:0.18142886817436335
# Epochs: 294: Nøyaktighet:0.723 | Tap:0.18141753996801446
# Epochs: 295: Nøyaktighet:0.723 | Tap:0.18140643706683818
# Epochs: 296: Nøyaktighet:0.722 | Tap:0.18139555498963267
# Epochs: 297: Nøyaktighet:0.723 | Tap:0.18138488934432764
# Epochs: 298: Nøyaktighet:0.724 | Tap:0.18137443582621138
# Epochs: 299: Nøyaktighet:0.725 | Tap:0.18136419021619307
# Epochs: 300: Nøyaktighet:0.725 | Tap:0.18135414837910002
# Epochs: 301: Nøyaktighet:0.725 | Tap:0.18134430626200806
# Epochs: 302: Nøyaktighet:0.727 | Tap:0.18133465989260594
# Epochs: 303: Nøyaktighet:0.727 | Tap:0.18132520537759161
# Epochs: 304: Nøyaktighet:0.728 | Tap:0.18131593890110087
# Epochs: 305: Nøyaktighet:0.729 | Tap:0.18130685672316701
# Epochs: 306: Nøyaktighet:0.731 | Tap:0.18129795517821112
# Epochs: 307: Nøyaktighet:0.731 | Tap:0.18128923067356248
# Epochs: 308: Nøyaktighet:0.732 | Tap:0.18128067968800854
# Epochs: 309: Nøyaktighet:0.732 | Tap:0.18127229877037337
# Epochs: 310: Nøyaktighet:0.732 | Tap:0.18126408453812468
# Epochs: 311: Nøyaktighet:0.732 | Tap:0.18125603367600834
# Epochs: 312: Nøyaktighet:0.735 | Tap:0.18124814293471053
# Epochs: 313: Nøyaktighet:0.734 | Tap:0.18124040912954575
# Epochs: 314: Nøyaktighet:0.735 | Tap:0.18123282913917152
# Epochs: 315: Nøyaktighet:0.735 | Tap:0.18122539990432848
# Epochs: 316: Nøyaktighet:0.734 | Tap:0.1812181184266054
# Epochs: 317: Nøyaktighet:0.734 | Tap:0.1812109817672291
# Epochs: 318: Nøyaktighet:0.734 | Tap:0.18120398704587798
# Epochs: 319: Nøyaktighet:0.734 | Tap:0.1811971314395195
# Epochs: 320: Nøyaktighet:0.734 | Tap:0.18119041218127074
# Epochs: 321: Nøyaktighet:0.734 | Tap:0.18118382655928147
# Epochs: 322: Nøyaktighet:0.734 | Tap:0.18117737191563948
# Epochs: 323: Nøyaktighet:0.734 | Tap:0.18117104564529796
# Epochs: 324: Nøyaktighet:0.734 | Tap:0.18116484519502374
# Epochs: 325: Nøyaktighet:0.733 | Tap:0.18115876806236678
# Epochs: 326: Nøyaktighet:0.733 | Tap:0.18115281179465006
# Epochs: 327: Nøyaktighet:0.733 | Tap:0.18114697398797974
# Epochs: 328: Nøyaktighet:0.733 | Tap:0.18114125228627462
# Epochs: 329: Nøyaktighet:0.733 | Tap:0.18113564438031518
# Epochs: 330: Nøyaktighet:0.734 | Tap:0.18113014800681168
# Epochs: 331: Nøyaktighet:0.736 | Tap:0.18112476094749025
# Epochs: 332: Nøyaktighet:0.735 | Tap:0.18111948102819792
# Epochs: 333: Nøyaktighet:0.735 | Tap:0.1811143061180247
# Epochs: 334: Nøyaktighet:0.737 | Tap:0.18110923412844368
# Epochs: 335: Nøyaktighet:0.737 | Tap:0.18110426301246793
# Epochs: 336: Nøyaktighet:0.738 | Tap:0.18109939076382425
# Epochs: 337: Nøyaktighet:0.738 | Tap:0.18109461541614344
# Epochs: 338: Nøyaktighet:0.737 | Tap:0.1810899350421665
# Epochs: 339: Nøyaktighet:0.737 | Tap:0.1810853477529668
# Epochs: 340: Nøyaktighet:0.737 | Tap:0.1810808516971877
# Epochs: 341: Nøyaktighet:0.738 | Tap:0.18107644506029508
# Epochs: 342: Nøyaktighet:0.738 | Tap:0.18107212606384504
# Epochs: 343: Nøyaktighet:0.738 | Tap:0.1810678929647662
# Epochs: 344: Nøyaktighet:0.738 | Tap:0.18106374405465583
# Epochs: 345: Nøyaktighet:0.738 | Tap:0.18105967765909062
# Epochs: 346: Nøyaktighet:0.738 | Tap:0.1810556921369506
# Epochs: 347: Nøyaktighet:0.738 | Tap:0.1810517858797568
# Epochs: 348: Nøyaktighet:0.737 | Tap:0.18104795731102197
# Epochs: 349: Nøyaktighet:0.738 | Tap:0.18104420488561448
# Epochs: 350: Nøyaktighet:0.738 | Tap:0.18104052708913426
# Epochs: 351: Nøyaktighet:0.737 | Tap:0.18103692243730193
# Epochs: 352: Nøyaktighet:0.739 | Tap:0.18103338947535957
# Epochs: 353: Nøyaktighet:0.739 | Tap:0.18102992677748334
# Epochs: 354: Nøyaktighet:0.739 | Tap:0.18102653294620832
# Epochs: 355: Nøyaktighet:0.738 | Tap:0.18102320661186422
# Epochs: 356: Nøyaktighet:0.738 | Tap:0.18101994643202257
# Epochs: 357: Nøyaktighet:0.738 | Tap:0.18101675109095505
# Epochs: 358: Nøyaktighet:0.737 | Tap:0.18101361929910212
# Epochs: 359: Nøyaktighet:0.738 | Tap:0.18101054979255282
# Epochs: 360: Nøyaktighet:0.738 | Tap:0.1810075413325345
# Epochs: 361: Nøyaktighet:0.739 | Tap:0.1810045927049127
# Epochs: 362: Nøyaktighet:0.739 | Tap:0.18100170271970145
# Epochs: 363: Nøyaktighet:0.739 | Tap:0.18099887021058253
# Epochs: 364: Nøyaktighet:0.739 | Tap:0.18099609403443498
# Epochs: 365: Nøyaktighet:0.74 | Tap:0.18099337307087368
# Epochs: 366: Nøyaktighet:0.74 | Tap:0.18099070622179705
# Epochs: 367: Nøyaktighet:0.74 | Tap:0.18098809241094402
# Epochs: 368: Nøyaktighet:0.739 | Tap:0.18098553058345937
# Epochs: 369: Nøyaktighet:0.739 | Tap:0.18098301970546807
# Epochs: 370: Nøyaktighet:0.739 | Tap:0.18098055876365823
# Epochs: 371: Nøyaktighet:0.74 | Tap:0.18097814676487167
# Epochs: 372: Nøyaktighet:0.74 | Tap:0.1809757827357034
# Epochs: 373: Nøyaktighet:0.741 | Tap:0.18097346572210854
# Epochs: 374: Nøyaktighet:0.741 | Tap:0.1809711947890175
# Epochs: 375: Nøyaktighet:0.742 | Tap:0.18096896901995826
# Epochs: 376: Nøyaktighet:0.742 | Tap:0.18096678751668657
# Epochs: 377: Nøyaktighet:0.743 | Tap:0.18096464939882362
# Epochs: 378: Nøyaktighet:0.743 | Tap:0.18096255380350038
# Epochs: 379: Nøyaktighet:0.743 | Tap:0.18096049988500956
# Epochs: 380: Nøyaktighet:0.743 | Tap:0.18095848681446416
# Epochs: 381: Nøyaktighet:0.743 | Tap:0.1809565137794629
# Epochs: 382: Nøyaktighet:0.744 | Tap:0.1809545799837625
# Epochs: 383: Nøyaktighet:0.744 | Tap:0.18095268464695613
# Epochs: 384: Nøyaktighet:0.744 | Tap:0.1809508270041584
# Epochs: 385: Nøyaktighet:0.744 | Tap:0.1809490063056968
# Epochs: 386: Nøyaktighet:0.744 | Tap:0.18094722181680908
# Epochs: 387: Nøyaktighet:0.744 | Tap:0.18094547281734652
# Epochs: 388: Nøyaktighet:0.744 | Tap:0.1809437586014835
# Epochs: 389: Nøyaktighet:0.744 | Tap:0.18094207847743263
# Epochs: 390: Nøyaktighet:0.744 | Tap:0.18094043176716526
# Epochs: 391: Nøyaktighet:0.744 | Tap:0.180938817806138
# Epochs: 392: Nøyaktighet:0.743 | Tap:0.18093723594302466
# Epochs: 393: Nøyaktighet:0.743 | Tap:0.18093568553945305
# Epochs: 394: Nøyaktighet:0.743 | Tap:0.18093416596974762
# Epochs: 395: Nøyaktighet:0.743 | Tap:0.18093267662067675
# Epochs: 396: Nøyaktighet:0.743 | Tap:0.1809312168912052
# Epochs: 397: Nøyaktighet:0.743 | Tap:0.1809297861922518
# Epochs: 398: Nøyaktighet:0.743 | Tap:0.1809283839464514
# Epochs: 399: Nøyaktighet:0.744 | Tap:0.180927009587922
# Epochs: 400: Nøyaktighet:0.745 | Tap:0.18092566256203635
# Epochs: 401: Nøyaktighet:0.744 | Tap:0.18092434232519797
# Epochs: 402: Nøyaktighet:0.744 | Tap:0.18092304834462197
# Epochs: 403: Nøyaktighet:0.745 | Tap:0.18092178009811988
# Epochs: 404: Nøyaktighet:0.745 | Tap:0.18092053707388883
# Epochs: 405: Nøyaktighet:0.745 | Tap:0.18091931877030515
# Epochs: 406: Nøyaktighet:0.745 | Tap:0.1809181246957218
# Epochs: 407: Nøyaktighet:0.745 | Tap:0.18091695436826993
# Epochs: 408: Nøyaktighet:0.745 | Tap:0.18091580731566456
# Epochs: 409: Nøyaktighet:0.745 | Tap:0.18091468307501374
# Epochs: 410: Nøyaktighet:0.745 | Tap:0.18091358119263184
# Epochs: 411: Nøyaktighet:0.745 | Tap:0.1809125012238565
# Epochs: 412: Nøyaktighet:0.745 | Tap:0.18091144273286897
# Epochs: 413: Nøyaktighet:0.745 | Tap:0.18091040529251853
# Epochs: 414: Nøyaktighet:0.745 | Tap:0.18090938848414975
# Epochs: 415: Nøyaktighet:0.745 | Tap:0.18090839189743382
# Epochs: 416: Nøyaktighet:0.745 | Tap:0.18090741513020264
# Epochs: 417: Nøyaktighet:0.745 | Tap:0.1809064577882868
# Epochs: 418: Nøyaktighet:0.745 | Tap:0.18090551948535627
# Epochs: 419: Nøyaktighet:0.745 | Tap:0.18090459984276466
# Epochs: 420: Nøyaktighet:0.745 | Tap:0.18090369848939625
# Epochs: 421: Nøyaktighet:0.745 | Tap:0.1809028150615163
# Epochs: 422: Nøyaktighet:0.744 | Tap:0.18090194920262423
# Epochs: 423: Nøyaktighet:0.744 | Tap:0.18090110056330969
# Epochs: 424: Nøyaktighet:0.743 | Tap:0.18090026880111162
# Epochs: 425: Nøyaktighet:0.743 | Tap:0.18089945358038
# Epochs: 426: Nøyaktighet:0.742 | Tap:0.18089865457214035
# Epochs: 427: Nøyaktighet:0.742 | Tap:0.18089787145396105
# Epochs: 428: Nøyaktighet:0.742 | Tap:0.1808971039098231
# Epochs: 429: Nøyaktighet:0.742 | Tap:0.1808963516299926
# Epochs: 430: Nøyaktighet:0.742 | Tap:0.18089561431089585
# Epochs: 431: Nøyaktighet:0.743 | Tap:0.18089489165499667
# Epochs: 432: Nøyaktighet:0.743 | Tap:0.18089418337067656
# Epochs: 433: Nøyaktighet:0.743 | Tap:0.18089348917211662
# Epochs: 434: Nøyaktighet:0.743 | Tap:0.1808928087791826
# Epochs: 435: Nøyaktighet:0.744 | Tap:0.18089214191731157
# Epochs: 436: Nøyaktighet:0.744 | Tap:0.18089148831740126
# Epochs: 437: Nøyaktighet:0.744 | Tap:0.1808908477157014
# Epochs: 438: Nøyaktighet:0.744 | Tap:0.18089021985370726
# Epochs: 439: Nøyaktighet:0.744 | Tap:0.18088960447805535
# Epochs: 440: Nøyaktighet:0.745 | Tap:0.18088900134042113
# Epochs: 441: Nøyaktighet:0.745 | Tap:0.18088841019741878
# Epochs: 442: Nøyaktighet:0.745 | Tap:0.1808878308105031
# Epochs: 443: Nøyaktighet:0.745 | Tap:0.18088726294587315
# Epochs: 444: Nøyaktighet:0.745 | Tap:0.18088670637437776
# Epochs: 445: Nøyaktighet:0.745 | Tap:0.1808861608714232
# Epochs: 446: Nøyaktighet:0.745 | Tap:0.1808856262168827
# Epochs: 447: Nøyaktighet:0.746 | Tap:0.18088510219500714
# Epochs: 448: Nøyaktighet:0.747 | Tap:0.18088458859433854
# Epochs: 449: Nøyaktighet:0.747 | Tap:0.1808840852076242
# Epochs: 450: Nøyaktighet:0.747 | Tap:0.18088359183173347
# Epochs: 451: Nøyaktighet:0.747 | Tap:0.1808831082675755
# Epochs: 452: Nøyaktighet:0.747 | Tap:0.18088263432001908
# Epochs: 453: Nøyaktighet:0.747 | Tap:0.18088216979781374
# Epochs: 454: Nøyaktighet:0.747 | Tap:0.1808817145135126
# Epochs: 455: Nøyaktighet:0.747 | Tap:0.18088126828339682
# Epochs: 456: Nøyaktighet:0.747 | Tap:0.18088083092740131
# Epochs: 457: Nøyaktighet:0.747 | Tap:0.1808804022690422
# Epochs: 458: Nøyaktighet:0.747 | Tap:0.18087998213534554
# Epochs: 459: Nøyaktighet:0.747 | Tap:0.18087957035677743
# Epochs: 460: Nøyaktighet:0.747 | Tap:0.1808791667671757
# Epochs: 461: Nøyaktighet:0.747 | Tap:0.1808787712036829
# Epochs: 462: Nøyaktighet:0.747 | Tap:0.1808783835066804
# Epochs: 463: Nøyaktighet:0.747 | Tap:0.18087800351972413
# Epochs: 464: Nøyaktighet:0.747 | Tap:0.18087763108948132
# Epochs: 465: Nøyaktighet:0.747 | Tap:0.18087726606566878
# Epochs: 466: Nøyaktighet:0.747 | Tap:0.18087690830099207
# Epochs: 467: Nøyaktighet:0.747 | Tap:0.1808765576510861
# Epochs: 468: Nøyaktighet:0.747 | Tap:0.18087621397445708
# Epochs: 469: Nøyaktighet:0.747 | Tap:0.18087587713242506
# Epochs: 470: Nøyaktighet:0.747 | Tap:0.18087554698906824
# Epochs: 471: Nøyaktighet:0.747 | Tap:0.18087522341116802
# Epochs: 472: Nøyaktighet:0.747 | Tap:0.1808749062681552
# Epochs: 473: Nøyaktighet:0.747 | Tap:0.18087459543205736
# Epochs: 474: Nøyaktighet:0.747 | Tap:0.18087429077744718
# Epochs: 475: Nøyaktighet:0.747 | Tap:0.18087399218139183
# Epochs: 476: Nøyaktighet:0.747 | Tap:0.18087369952340332
# Epochs: 477: Nøyaktighet:0.747 | Tap:0.18087341268538995
# Epochs: 478: Nøyaktighet:0.747 | Tap:0.18087313155160858
# Epochs: 479: Nøyaktighet:0.747 | Tap:0.180872856008618
# Epochs: 480: Nøyaktighet:0.747 | Tap:0.18087258594523295
# Epochs: 481: Nøyaktighet:0.747 | Tap:0.1808723212524796
# Epochs: 482: Nøyaktighet:0.747 | Tap:0.18087206182355123
# Epochs: 483: Nøyaktighet:0.747 | Tap:0.1808718075537654
# Epochs: 484: Nøyaktighet:0.747 | Tap:0.1808715583405214
# Epochs: 485: Nøyaktighet:0.747 | Tap:0.1808713140832591
# Epochs: 486: Nøyaktighet:0.747 | Tap:0.18087107468341831
# Epochs: 487: Nøyaktighet:0.747 | Tap:0.18087084004439902
# Epochs: 488: Nøyaktighet:0.747 | Tap:0.18087061007152228
# Epochs: 489: Nøyaktighet:0.747 | Tap:0.18087038467199204
# Epochs: 490: Nøyaktighet:0.747 | Tap:0.18087016375485784
# Epochs: 491: Nøyaktighet:0.747 | Tap:0.18086994723097813
# Epochs: 492: Nøyaktighet:0.747 | Tap:0.18086973501298395
# Epochs: 493: Nøyaktighet:0.747 | Tap:0.18086952701524406
# Epochs: 494: Nøyaktighet:0.747 | Tap:0.18086932315383003
# Epochs: 495: Nøyaktighet:0.747 | Tap:0.18086912334648286
# Epochs: 496: Nøyaktighet:0.747 | Tap:0.18086892751257932
# Epochs: 497: Nøyaktighet:0.747 | Tap:0.1808687355730995
# Epochs: 498: Nøyaktighet:0.747 | Tap:0.18086854745059516
# Epochs: 499: Nøyaktighet:0.747 | Tap:0.18086836306915827
# Epochs: 500: Nøyaktighet:0.747 | Tap:0.1808681823543904
# Epochs: 501: Nøyaktighet:0.747 | Tap:0.18086800523337274
# Epochs: 502: Nøyaktighet:0.747 | Tap:0.18086783163463666
# Epochs: 503: Nøyaktighet:0.747 | Tap:0.1808676614881348
# Epochs: 504: Nøyaktighet:0.748 | Tap:0.18086749472521302
# Epochs: 505: Nøyaktighet:0.748 | Tap:0.1808673312785824
# Epochs: 506: Nøyaktighet:0.748 | Tap:0.1808671710822923
# Epochs: 507: Nøyaktighet:0.748 | Tap:0.1808670140717037
# Epochs: 508: Nøyaktighet:0.748 | Tap:0.18086686018346287
# Epochs: 509: Nøyaktighet:0.748 | Tap:0.18086670935547636
# Epochs: 510: Nøyaktighet:0.748 | Tap:0.18086656152688532
# Epochs: 511: Nøyaktighet:0.748 | Tap:0.18086641663804143
# Epochs: 512: Nøyaktighet:0.748 | Tap:0.18086627463048244
# Epochs: 513: Nøyaktighet:0.748 | Tap:0.1808661354469089
# Epochs: 514: Nøyaktighet:0.747 | Tap:0.18086599903116085
# Epochs: 515: Nøyaktighet:0.747 | Tap:0.18086586532819518
# Epochs: 516: Nøyaktighet:0.748 | Tap:0.18086573428406347
# Epochs: 517: Nøyaktighet:0.748 | Tap:0.18086560584589023
# Epochs: 518: Nøyaktighet:0.748 | Tap:0.18086547996185143
# Epochs: 519: Nøyaktighet:0.749 | Tap:0.18086535658115374
# Epochs: 520: Nøyaktighet:0.749 | Tap:0.18086523565401402
# Epochs: 521: Nøyaktighet:0.749 | Tap:0.18086511713163905
# Epochs: 522: Nøyaktighet:0.749 | Tap:0.18086500096620609
# Epochs: 523: Nøyaktighet:0.749 | Tap:0.18086488711084342
# Epochs: 524: Nøyaktighet:0.749 | Tap:0.1808647755196115
# Epochs: 525: Nøyaktighet:0.749 | Tap:0.18086466614748437
# Epochs: 526: Nøyaktighet:0.749 | Tap:0.18086455895033154
# Epochs: 527: Nøyaktighet:0.749 | Tap:0.18086445388490008
# Epochs: 528: Nøyaktighet:0.749 | Tap:0.1808643509087974
# Epochs: 529: Nøyaktighet:0.749 | Tap:0.1808642499804738
# Epochs: 530: Nøyaktighet:0.749 | Tap:0.18086415105920595
# Epochs: 531: Nøyaktighet:0.749 | Tap:0.18086405410508047
# Epochs: 532: Nøyaktighet:0.749 | Tap:0.18086395907897765
# Epochs: 533: Nøyaktighet:0.749 | Tap:0.1808638659425558
# Epochs: 534: Nøyaktighet:0.75 | Tap:0.18086377465823572
# Epochs: 535: Nøyaktighet:0.75 | Tap:0.18086368518918558
# Epochs: 536: Nøyaktighet:0.75 | Tap:0.18086359749930603
# Epochs: 537: Nøyaktighet:0.75 | Tap:0.1808635115532155
# Epochs: 538: Nøyaktighet:0.75 | Tap:0.1808634273162363
# Epochs: 539: Nøyaktighet:0.75 | Tap:0.18086334475438026
# Epochs: 540: Nøyaktighet:0.75 | Tap:0.180863263834335
# Epochs: 541: Nøyaktighet:0.75 | Tap:0.18086318452345082
# Epochs: 542: Nøyaktighet:0.75 | Tap:0.18086310678972728
# Epochs: 543: Nøyaktighet:0.75 | Tap:0.18086303060180023
# Epochs: 544: Nøyaktighet:0.75 | Tap:0.18086295592892943
# Epochs: 545: Nøyaktighet:0.75 | Tap:0.18086288274098586
# Epochs: 546: Nøyaktighet:0.75 | Tap:0.18086281100843968
# Epochs: 547: Nøyaktighet:0.75 | Tap:0.18086274070234828
# Epochs: 548: Nøyaktighet:0.75 | Tap:0.18086267179434476
# Epochs: 549: Nøyaktighet:0.75 | Tap:0.18086260425662617
# Epochs: 550: Nøyaktighet:0.75 | Tap:0.1808625380619427
# Epochs: 551: Nøyaktighet:0.75 | Tap:0.18086247318358625
# Epochs: 552: Nøyaktighet:0.75 | Tap:0.1808624095953799
# Epochs: 553: Nøyaktighet:0.75 | Tap:0.1808623472716675
# Epochs: 554: Nøyaktighet:0.75 | Tap:0.18086228618730282
# Epochs: 555: Nøyaktighet:0.75 | Tap:0.18086222631763993
# Epochs: 556: Nøyaktighet:0.75 | Tap:0.18086216763852295
# Epochs: 557: Nøyaktighet:0.75 | Tap:0.18086211012627643
# Epochs: 558: Nøyaktighet:0.751 | Tap:0.18086205375769565
# Epochs: 559: Nøyaktighet:0.751 | Tap:0.18086199851003745
# Epochs: 560: Nøyaktighet:0.751 | Tap:0.18086194436101102
# Epochs: 561: Nøyaktighet:0.751 | Tap:0.18086189128876862
# Epochs: 562: Nøyaktighet:0.751 | Tap:0.18086183927189722
# Epochs: 563: Nøyaktighet:0.751 | Tap:0.1808617882894095
# Epochs: 564: Nøyaktighet:0.751 | Tap:0.18086173832073557
# Epochs: 565: Nøyaktighet:0.751 | Tap:0.1808616893457146
# Epochs: 566: Nøyaktighet:0.751 | Tap:0.1808616413445866
# Epochs: 567: Nøyaktighet:0.751 | Tap:0.18086159429798468
# Epochs: 568: Nøyaktighet:0.751 | Tap:0.18086154818692704
# Epochs: 569: Nøyaktighet:0.751 | Tap:0.1808615029928094
# Epochs: 570: Nøyaktighet:0.751 | Tap:0.18086145869739734
# Epochs: 571: Nøyaktighet:0.751 | Tap:0.1808614152828191
# Epochs: 572: Nøyaktighet:0.752 | Tap:0.1808613727315585
# Epochs: 573: Nøyaktighet:0.752 | Tap:0.1808613310264475
# Epochs: 574: Nøyaktighet:0.752 | Tap:0.18086129015065952
# Epochs: 575: Nøyaktighet:0.753 | Tap:0.18086125008770274
# Epochs: 576: Nøyaktighet:0.753 | Tap:0.18086121082141302
# Epochs: 577: Nøyaktighet:0.753 | Tap:0.18086117233594798
# Epochs: 578: Nøyaktighet:0.753 | Tap:0.18086113461578013
# Epochs: 579: Nøyaktighet:0.753 | Tap:0.18086109764569072
# Epochs: 580: Nøyaktighet:0.753 | Tap:0.18086106141076383
# Epochs: 581: Nøyaktighet:0.753 | Tap:0.18086102589638
# Epochs: 582: Nøyaktighet:0.753 | Tap:0.18086099108821058
# Epochs: 583: Nøyaktighet:0.753 | Tap:0.18086095697221183
# Epochs: 584: Nøyaktighet:0.753 | Tap:0.1808609235346193
# Epochs: 585: Nøyaktighet:0.752 | Tap:0.1808608907619423
# Epochs: 586: Nøyaktighet:0.752 | Tap:0.18086085864095838
# Epochs: 587: Nøyaktighet:0.752 | Tap:0.18086082715870813
# Epochs: 588: Nøyaktighet:0.752 | Tap:0.1808607963024897
# Epochs: 589: Nøyaktighet:0.752 | Tap:0.18086076605985388
# Epochs: 590: Nøyaktighet:0.752 | Tap:0.18086073641859923
# Epochs: 591: Nøyaktighet:0.752 | Tap:0.18086070736676663
# Epochs: 592: Nøyaktighet:0.752 | Tap:0.18086067889263505
# Epochs: 593: Nøyaktighet:0.752 | Tap:0.18086065098471638
# Epochs: 594: Nøyaktighet:0.752 | Tap:0.1808606236317511
# Epochs: 595: Nøyaktighet:0.752 | Tap:0.18086059682270345
# Epochs: 596: Nøyaktighet:0.752 | Tap:0.18086057054675728
# Epochs: 597: Nøyaktighet:0.751 | Tap:0.18086054479331148
# Epochs: 598: Nøyaktighet:0.751 | Tap:0.1808605195519757
# Epochs: 599: Nøyaktighet:0.751 | Tap:0.18086049481256627
# Epochs: 600: Nøyaktighet:0.751 | Tap:0.18086047056510204
# Epochs: 601: Nøyaktighet:0.75 | Tap:0.1808604467998004
# Epochs: 602: Nøyaktighet:0.75 | Tap:0.1808604235070731
# Epochs: 603: Nøyaktighet:0.75 | Tap:0.1808604006775228
# Epochs: 604: Nøyaktighet:0.751 | Tap:0.18086037830193882
# Epochs: 605: Nøyaktighet:0.751 | Tap:0.1808603563712938
# Epochs: 606: Nøyaktighet:0.751 | Tap:0.18086033487673983
# Epochs: 607: Nøyaktighet:0.751 | Tap:0.18086031380960496
# Epochs: 608: Nøyaktighet:0.751 | Tap:0.1808602931613898
# Epochs: 609: Nøyaktighet:0.751 | Tap:0.18086027292376372
# Epochs: 610: Nøyaktighet:0.751 | Tap:0.18086025308856205
# Epochs: 611: Nøyaktighet:0.751 | Tap:0.18086023364778225
# Epochs: 612: Nøyaktighet:0.751 | Tap:0.18086021459358106
# Epochs: 613: Nøyaktighet:0.751 | Tap:0.1808601959182712
# Epochs: 614: Nøyaktighet:0.751 | Tap:0.18086017761431816
# Epochs: 615: Nøyaktighet:0.751 | Tap:0.18086015967433736
# Epochs: 616: Nøyaktighet:0.751 | Tap:0.18086014209109094
# Epochs: 617: Nøyaktighet:0.751 | Tap:0.18086012485748518
# Epochs: 618: Nøyaktighet:0.751 | Tap:0.1808601079665672
# Epochs: 619: Nøyaktighet:0.751 | Tap:0.18086009141152257
# Epochs: 620: Nøyaktighet:0.751 | Tap:0.18086007518567226
# Epochs: 621: Nøyaktighet:0.751 | Tap:0.18086005928247004
# Epochs: 622: Nøyaktighet:0.751 | Tap:0.18086004369550002
# Epochs: 623: Nøyaktighet:0.751 | Tap:0.1808600284184737
# Epochs: 624: Nøyaktighet:0.751 | Tap:0.1808600134452278
# Epochs: 625: Nøyaktighet:0.751 | Tap:0.18085999876972148
# Epochs: 626: Nøyaktighet:0.751 | Tap:0.18085998438603407
# Epochs: 627: Nøyaktighet:0.751 | Tap:0.1808599702883626
# Epochs: 628: Nøyaktighet:0.751 | Tap:0.18085995647101966
# Epochs: 629: Nøyaktighet:0.751 | Tap:0.18085994292843074
# Epochs: 630: Nøyaktighet:0.751 | Tap:0.18085992965513228
# Epochs: 631: Nøyaktighet:0.751 | Tap:0.1808599166457693
# Epochs: 632: Nøyaktighet:0.751 | Tap:0.18085990389509346
# Epochs: 633: Nøyaktighet:0.751 | Tap:0.1808598913979606
# Epochs: 634: Nøyaktighet:0.751 | Tap:0.180859879149329
# Epochs: 635: Nøyaktighet:0.751 | Tap:0.18085986714425714
# Epochs: 636: Nøyaktighet:0.751 | Tap:0.18085985537790178
# Epochs: 637: Nøyaktighet:0.751 | Tap:0.1808598438455159
# Epochs: 638: Nøyaktighet:0.751 | Tap:0.18085983254244706
# Epochs: 639: Nøyaktighet:0.751 | Tap:0.18085982146413523
# Epochs: 640: Nøyaktighet:0.751 | Tap:0.180859810606111
# Epochs: 641: Nøyaktighet:0.751 | Tap:0.18085979996399396
# Epochs: 642: Nøyaktighet:0.751 | Tap:0.18085978953349074
# Epochs: 643: Nøyaktighet:0.751 | Tap:0.18085977931039338
# Epochs: 644: Nøyaktighet:0.751 | Tap:0.18085976929057762
# Epochs: 645: Nøyaktighet:0.751 | Tap:0.18085975947000105
# Epochs: 646: Nøyaktighet:0.751 | Tap:0.18085974984470188
# Epochs: 647: Nøyaktighet:0.751 | Tap:0.18085974041079697
# Epochs: 648: Nøyaktighet:0.751 | Tap:0.18085973116448037
# Epochs: 649: Nøyaktighet:0.751 | Tap:0.18085972210202195
# Epochs: 650: Nøyaktighet:0.751 | Tap:0.18085971321976563
# Epochs: 651: Nøyaktighet:0.751 | Tap:0.18085970451412808
# Epochs: 652: Nøyaktighet:0.751 | Tap:0.1808596959815972
# Epochs: 653: Nøyaktighet:0.751 | Tap:0.18085968761873084
# Epochs: 654: Nøyaktighet:0.751 | Tap:0.18085967942215514
# Epochs: 655: Nøyaktighet:0.751 | Tap:0.18085967138856343
# Epochs: 656: Nøyaktighet:0.751 | Tap:0.18085966351471477
# Epochs: 657: Nøyaktighet:0.751 | Tap:0.18085965579743266
# Epochs: 658: Nøyaktighet:0.751 | Tap:0.1808596482336038
# Epochs: 659: Nøyaktighet:0.751 | Tap:0.18085964082017675
# Epochs: 660: Nøyaktighet:0.751 | Tap:0.18085963355416076
# Epochs: 661: Nøyaktighet:0.751 | Tap:0.1808596264326246
# Epochs: 662: Nøyaktighet:0.751 | Tap:0.18085961945269532
# Epochs: 663: Nøyaktighet:0.751 | Tap:0.180859612611557
# Epochs: 664: Nøyaktighet:0.751 | Tap:0.18085960590644987
# Epochs: 665: Nøyaktighet:0.751 | Tap:0.18085959933466894
# Epochs: 666: Nøyaktighet:0.751 | Tap:0.18085959289356304
# Epochs: 667: Nøyaktighet:0.751 | Tap:0.1808595865805337
# Epochs: 668: Nøyaktighet:0.751 | Tap:0.1808595803930341
# Epochs: 669: Nøyaktighet:0.751 | Tap:0.1808595743285682
# Epochs: 670: Nøyaktighet:0.751 | Tap:0.1808595683846894
# Epochs: 671: Nøyaktighet:0.751 | Tap:0.18085956255899988
# Epochs: 672: Nøyaktighet:0.751 | Tap:0.18085955684914945
# Epochs: 673: Nøyaktighet:0.751 | Tap:0.1808595512528347
# Epochs: 674: Nøyaktighet:0.751 | Tap:0.18085954576779795
# Epochs: 675: Nøyaktighet:0.751 | Tap:0.18085954039182658
# Epochs: 676: Nøyaktighet:0.751 | Tap:0.1808595351227517
# Epochs: 677: Nøyaktighet:0.751 | Tap:0.1808595299584478
# Epochs: 678: Nøyaktighet:0.751 | Tap:0.18085952489683155
# Epochs: 679: Nøyaktighet:0.751 | Tap:0.18085951993586094
# Epochs: 680: Nøyaktighet:0.751 | Tap:0.18085951507353468
# Epochs: 681: Nøyaktighet:0.751 | Tap:0.18085951030789135
# Epochs: 682: Nøyaktighet:0.751 | Tap:0.18085950563700834
# Epochs: 683: Nøyaktighet:0.751 | Tap:0.18085950105900142
# Epochs: 684: Nøyaktighet:0.751 | Tap:0.18085949657202377
# Epochs: 685: Nøyaktighet:0.751 | Tap:0.18085949217426528
# Epochs: 686: Nøyaktighet:0.751 | Tap:0.18085948786395192
# Epochs: 687: Nøyaktighet:0.751 | Tap:0.18085948363934484
# Epochs: 688: Nøyaktighet:0.751 | Tap:0.18085947949873976
# Epochs: 689: Nøyaktighet:0.751 | Tap:0.1808594754404664
# Epochs: 690: Nøyaktighet:0.751 | Tap:0.1808594714628876
# Epochs: 691: Nøyaktighet:0.751 | Tap:0.1808594675643988
# Epochs: 692: Nøyaktighet:0.751 | Tap:0.18085946374342732
# Epochs: 693: Nøyaktighet:0.751 | Tap:0.18085945999843173
# Epochs: 694: Nøyaktighet:0.751 | Tap:0.18085945632790135
# Epochs: 695: Nøyaktighet:0.751 | Tap:0.1808594527303554
# Epochs: 696: Nøyaktighet:0.751 | Tap:0.18085944920434266
# Epochs: 697: Nøyaktighet:0.751 | Tap:0.18085944574844076
# Epochs: 698: Nøyaktighet:0.751 | Tap:0.1808594423612555
# Epochs: 699: Nøyaktighet:0.751 | Tap:0.18085943904142063
# Epochs: 700: Nøyaktighet:0.751 | Tap:0.18085943578759675
# Epochs: 701: Nøyaktighet:0.751 | Tap:0.18085943259847131
# Epochs: 702: Nøyaktighet:0.751 | Tap:0.18085942947275788
# Epochs: 703: Nøyaktighet:0.751 | Tap:0.18085942640919556
# Epochs: 704: Nøyaktighet:0.751 | Tap:0.18085942340654845
# Epochs: 705: Nøyaktighet:0.751 | Tap:0.18085942046360526
# Epochs: 706: Nøyaktighet:0.751 | Tap:0.18085941757917892
# Epochs: 707: Nøyaktighet:0.751 | Tap:0.18085941475210582
# Epochs: 708: Nøyaktighet:0.751 | Tap:0.18085941198124544
# Epochs: 709: Nøyaktighet:0.751 | Tap:0.18085940926548014
# Epochs: 710: Nøyaktighet:0.751 | Tap:0.18085940660371433
# Epochs: 711: Nøyaktighet:0.751 | Tap:0.1808594039948743
# Epochs: 712: Nøyaktighet:0.751 | Tap:0.18085940143790763
# Epochs: 713: Nøyaktighet:0.751 | Tap:0.18085939893178282
# Epochs: 714: Nøyaktighet:0.751 | Tap:0.18085939647548901
# Epochs: 715: Nøyaktighet:0.751 | Tap:0.1808593940680353
# Epochs: 716: Nøyaktighet:0.751 | Tap:0.18085939170845053
# Epochs: 717: Nøyaktighet:0.751 | Tap:0.18085938939578283
# Epochs: 718: Nøyaktighet:0.751 | Tap:0.18085938712909938
# Epochs: 719: Nøyaktighet:0.751 | Tap:0.1808593849074857
# Epochs: 720: Nøyaktighet:0.751 | Tap:0.18085938273004576
# Epochs: 721: Nøyaktighet:0.751 | Tap:0.1808593805959011
# Epochs: 722: Nøyaktighet:0.751 | Tap:0.18085937850419076
# Epochs: 723: Nøyaktighet:0.751 | Tap:0.18085937645407116
# Epochs: 724: Nøyaktighet:0.751 | Tap:0.18085937444471517
# Epochs: 725: Nøyaktighet:0.751 | Tap:0.18085937247531225
# Epochs: 726: Nøyaktighet:0.751 | Tap:0.18085937054506804
# Epochs: 727: Nøyaktighet:0.751 | Tap:0.18085936865320376
# Epochs: 728: Nøyaktighet:0.751 | Tap:0.18085936679895642
# Epochs: 729: Nøyaktighet:0.751 | Tap:0.18085936498157792
# Epochs: 730: Nøyaktighet:0.751 | Tap:0.18085936320033527
# Epochs: 731: Nøyaktighet:0.751 | Tap:0.18085936145450984
# Epochs: 732: Nøyaktighet:0.751 | Tap:0.18085935974339742
# Epochs: 733: Nøyaktighet:0.751 | Tap:0.1808593580663078
# Epochs: 734: Nøyaktighet:0.751 | Tap:0.18085935642256443
# Epochs: 735: Nøyaktighet:0.751 | Tap:0.18085935481150428
# Epochs: 736: Nøyaktighet:0.751 | Tap:0.18085935323247748
# Epochs: 737: Nøyaktighet:0.751 | Tap:0.18085935168484707
# Epochs: 738: Nøyaktighet:0.751 | Tap:0.18085935016798876
# Epochs: 739: Nøyaktighet:0.751 | Tap:0.1808593486812907
# Epochs: 740: Nøyaktighet:0.751 | Tap:0.18085934722415317
# Epochs: 741: Nøyaktighet:0.751 | Tap:0.18085934579598836
# Epochs: 742: Nøyaktighet:0.751 | Tap:0.18085934439622023
# Epochs: 743: Nøyaktighet:0.751 | Tap:0.1808593430242841
# Epochs: 744: Nøyaktighet:0.751 | Tap:0.18085934167962658
# Epochs: 745: Nøyaktighet:0.751 | Tap:0.18085934036170528
# Epochs: 746: Nøyaktighet:0.751 | Tap:0.18085933906998855
# Epochs: 747: Nøyaktighet:0.751 | Tap:0.18085933780395533
# Epochs: 748: Nøyaktighet:0.751 | Tap:0.180859336563095
# Epochs: 749: Nøyaktighet:0.751 | Tap:0.18085933534690696
# Epochs: 750: Nøyaktighet:0.751 | Tap:0.18085933415490063
# Epochs: 751: Nøyaktighet:0.751 | Tap:0.18085933298659526
# Epochs: 752: Nøyaktighet:0.751 | Tap:0.1808593318415195
# Epochs: 753: Nøyaktighet:0.751 | Tap:0.1808593307192115
# Epochs: 754: Nøyaktighet:0.751 | Tap:0.18085932961921855
# Epochs: 755: Nøyaktighet:0.751 | Tap:0.1808593285410969
# Epochs: 756: Nøyaktighet:0.751 | Tap:0.18085932748441172
# Epochs: 757: Nøyaktighet:0.751 | Tap:0.18085932644873673
# Epochs: 758: Nøyaktighet:0.751 | Tap:0.18085932543365418
# Epochs: 759: Nøyaktighet:0.751 | Tap:0.18085932443875466
# Epochs: 760: Nøyaktighet:0.751 | Tap:0.18085932346363684
# Epochs: 761: Nøyaktighet:0.751 | Tap:0.18085932250790732
# Epochs: 762: Nøyaktighet:0.751 | Tap:0.18085932157118065
# Epochs: 763: Nøyaktighet:0.751 | Tap:0.18085932065307894
# Epochs: 764: Nøyaktighet:0.751 | Tap:0.18085931975323194
# Epochs: 765: Nøyaktighet:0.751 | Tap:0.1808593188712766
# Epochs: 766: Nøyaktighet:0.751 | Tap:0.18085931800685723
# Epochs: 767: Nøyaktighet:0.751 | Tap:0.18085931715962505
# Epochs: 768: Nøyaktighet:0.751 | Tap:0.18085931632923843
# Epochs: 769: Nøyaktighet:0.751 | Tap:0.18085931551536236
# Epochs: 770: Nøyaktighet:0.751 | Tap:0.18085931471766856
# Epochs: 771: Nøyaktighet:0.751 | Tap:0.18085931393583526
# Epochs: 772: Nøyaktighet:0.751 | Tap:0.18085931316954715
# Epochs: 773: Nøyaktighet:0.751 | Tap:0.18085931241849507
# Epochs: 774: Nøyaktighet:0.751 | Tap:0.18085931168237607
# Epochs: 775: Nøyaktighet:0.751 | Tap:0.1808593109608933
# Epochs: 776: Nøyaktighet:0.751 | Tap:0.1808593102537557
# Epochs: 777: Nøyaktighet:0.751 | Tap:0.18085930956067797
# Epochs: 778: Nøyaktighet:0.751 | Tap:0.1808593088813807
# Epochs: 779: Nøyaktighet:0.751 | Tap:0.18085930821558974
# Epochs: 780: Nøyaktighet:0.751 | Tap:0.18085930756303661
# Epochs: 781: Nøyaktighet:0.751 | Tap:0.18085930692345809
# Epochs: 782: Nøyaktighet:0.751 | Tap:0.1808593062965962
# Epochs: 783: Nøyaktighet:0.751 | Tap:0.18085930568219805
# Epochs: 784: Nøyaktighet:0.751 | Tap:0.18085930508001594
# Epochs: 785: Nøyaktighet:0.751 | Tap:0.18085930448980678
# Epochs: 786: Nøyaktighet:0.752 | Tap:0.18085930391133268
# Epochs: 787: Nøyaktighet:0.752 | Tap:0.18085930334436023
# Epochs: 788: Nøyaktighet:0.752 | Tap:0.18085930278866072
# Epochs: 789: Nøyaktighet:0.752 | Tap:0.18085930224401012
# Epochs: 790: Nøyaktighet:0.752 | Tap:0.18085930171018855
# Epochs: 791: Nøyaktighet:0.752 | Tap:0.18085930118698088
# Epochs: 792: Nøyaktighet:0.752 | Tap:0.18085930067417594
# Epochs: 793: Nøyaktighet:0.752 | Tap:0.18085930017156693
# Epochs: 794: Nøyaktighet:0.752 | Tap:0.18085929967895117
# Epochs: 795: Nøyaktighet:0.752 | Tap:0.1808592991961299
# Epochs: 796: Nøyaktighet:0.752 | Tap:0.1808592987229084
# Epochs: 797: Nøyaktighet:0.752 | Tap:0.1808592982590958
# Epochs: 798: Nøyaktighet:0.752 | Tap:0.18085929780450496
# Epochs: 799: Nøyaktighet:0.752 | Tap:0.1808592973589526
# Epochs: 800: Nøyaktighet:0.752 | Tap:0.18085929692225897
# Epochs: 801: Nøyaktighet:0.752 | Tap:0.18085929649424798
# Epochs: 802: Nøyaktighet:0.752 | Tap:0.1808592960747469
# Epochs: 803: Nøyaktighet:0.752 | Tap:0.1808592956635866
# Epochs: 804: Nøyaktighet:0.752 | Tap:0.18085929526060124
# Epochs: 805: Nøyaktighet:0.752 | Tap:0.1808592948656282
# Epochs: 806: Nøyaktighet:0.752 | Tap:0.18085929447850824
# Epochs: 807: Nøyaktighet:0.752 | Tap:0.18085929409908522
# Epochs: 808: Nøyaktighet:0.752 | Tap:0.18085929372720602
# Epochs: 809: Nøyaktighet:0.752 | Tap:0.18085929336272075
# Epochs: 810: Nøyaktighet:0.752 | Tap:0.18085929300548237
# Epochs: 811: Nøyaktighet:0.752 | Tap:0.18085929265534667
# Epochs: 812: Nøyaktighet:0.752 | Tap:0.18085929231217263
# Epochs: 813: Nøyaktighet:0.752 | Tap:0.18085929197582165
# Epochs: 814: Nøyaktighet:0.752 | Tap:0.18085929164615816
# Epochs: 815: Nøyaktighet:0.752 | Tap:0.1808592913230492
# Epochs: 816: Nøyaktighet:0.752 | Tap:0.18085929100636447
# Epochs: 817: Nøyaktighet:0.752 | Tap:0.1808592906959761
# Epochs: 818: Nøyaktighet:0.752 | Tap:0.180859290391759
# Epochs: 819: Nøyaktighet:0.752 | Tap:0.18085929009359045
# Epochs: 820: Nøyaktighet:0.752 | Tap:0.18085928980135024
# Epochs: 821: Nøyaktighet:0.752 | Tap:0.1808592895149204
# Epochs: 822: Nøyaktighet:0.752 | Tap:0.18085928923418546
# Epochs: 823: Nøyaktighet:0.752 | Tap:0.18085928895903217
# Epochs: 824: Nøyaktighet:0.752 | Tap:0.18085928868934958
# Epochs: 825: Nøyaktighet:0.752 | Tap:0.1808592884250289
# Epochs: 826: Nøyaktighet:0.752 | Tap:0.1808592881659635
# Epochs: 827: Nøyaktighet:0.752 | Tap:0.18085928791204892
# Epochs: 828: Nøyaktighet:0.752 | Tap:0.18085928766318274
# Epochs: 829: Nøyaktighet:0.752 | Tap:0.18085928741926455
# Epochs: 830: Nøyaktighet:0.752 | Tap:0.18085928718019603
# Epochs: 831: Nøyaktighet:0.752 | Tap:0.1808592869458807
# Epochs: 832: Nøyaktighet:0.752 | Tap:0.18085928671622406
# Epochs: 833: Nøyaktighet:0.752 | Tap:0.1808592864911335
# Epochs: 834: Nøyaktighet:0.752 | Tap:0.18085928627051825
# Epochs: 835: Nøyaktighet:0.752 | Tap:0.1808592860542893
# Epochs: 836: Nøyaktighet:0.752 | Tap:0.18085928584235944
# Epochs: 837: Nøyaktighet:0.752 | Tap:0.18085928563464318
# Epochs: 838: Nøyaktighet:0.752 | Tap:0.18085928543105678
# Epochs: 839: Nøyaktighet:0.752 | Tap:0.18085928523151812
# Epochs: 840: Nøyaktighet:0.752 | Tap:0.1808592850359467
# Epochs: 841: Nøyaktighet:0.752 | Tap:0.18085928484426364
# Epochs: 842: Nøyaktighet:0.752 | Tap:0.18085928465639164
# Epochs: 843: Nøyaktighet:0.752 | Tap:0.1808592844722549
# Epochs: 844: Nøyaktighet:0.752 | Tap:0.1808592842917792
# Epochs: 845: Nøyaktighet:0.752 | Tap:0.18085928411489174
# Epochs: 846: Nøyaktighet:0.752 | Tap:0.18085928394152115
# Epochs: 847: Nøyaktighet:0.752 | Tap:0.18085928377159752
# Epochs: 848: Nøyaktighet:0.752 | Tap:0.18085928360505227
# Epochs: 849: Nøyaktighet:0.752 | Tap:0.1808592834418183
# Epochs: 850: Nøyaktighet:0.752 | Tap:0.18085928328182974
# Epochs: 851: Nøyaktighet:0.752 | Tap:0.1808592831250221
# Epochs: 852: Nøyaktighet:0.752 | Tap:0.18085928297133205
# Epochs: 853: Nøyaktighet:0.752 | Tap:0.18085928282069766
# Epochs: 854: Nøyaktighet:0.752 | Tap:0.1808592826730582
# Epochs: 855: Nøyaktighet:0.752 | Tap:0.18085928252835412
# Epochs: 856: Nøyaktighet:0.752 | Tap:0.180859282386527
# Epochs: 857: Nøyaktighet:0.752 | Tap:0.18085928224751965
# Epochs: 858: Nøyaktighet:0.752 | Tap:0.18085928211127603
# Epochs: 859: Nøyaktighet:0.752 | Tap:0.1808592819777412
# Epochs: 860: Nøyaktighet:0.752 | Tap:0.1808592818468613
# Epochs: 861: Nøyaktighet:0.752 | Tap:0.18085928171858354
# Epochs: 862: Nøyaktighet:0.752 | Tap:0.1808592815928561
# Epochs: 863: Nøyaktighet:0.752 | Tap:0.18085928146962843
# Epochs: 864: Nøyaktighet:0.752 | Tap:0.18085928134885074
# Epochs: 865: Nøyaktighet:0.752 | Tap:0.18085928123047432
# Epochs: 866: Nøyaktighet:0.752 | Tap:0.18085928111445143
# Epochs: 867: Nøyaktighet:0.752 | Tap:0.18085928100073528
# Epochs: 868: Nøyaktighet:0.752 | Tap:0.18085928088928
# Epochs: 869: Nøyaktighet:0.752 | Tap:0.18085928078004063
# Epochs: 870: Nøyaktighet:0.752 | Tap:0.18085928067297316
# Epochs: 871: Nøyaktighet:0.752 | Tap:0.1808592805680343
# Epochs: 872: Nøyaktighet:0.752 | Tap:0.18085928046518188
# Epochs: 873: Nøyaktighet:0.752 | Tap:0.18085928036437435
# Epochs: 874: Nøyaktighet:0.752 | Tap:0.180859280265571
# Epochs: 875: Nøyaktighet:0.752 | Tap:0.18085928016873204
# Epochs: 876: Nøyaktighet:0.752 | Tap:0.18085928007381835
# Epochs: 877: Nøyaktighet:0.752 | Tap:0.1808592799807918
# Epochs: 878: Nøyaktighet:0.752 | Tap:0.1808592798896147
# Epochs: 879: Nøyaktighet:0.752 | Tap:0.18085927980025035
# Epochs: 880: Nøyaktighet:0.752 | Tap:0.18085927971266272
# Epochs: 881: Nøyaktighet:0.752 | Tap:0.1808592796268165
# Epochs: 882: Nøyaktighet:0.752 | Tap:0.18085927954267697
# Epochs: 883: Nøyaktighet:0.752 | Tap:0.1808592794602103
# Epochs: 884: Nøyaktighet:0.752 | Tap:0.18085927937938323
# Epochs: 885: Nøyaktighet:0.752 | Tap:0.18085927930016304
# Epochs: 886: Nøyaktighet:0.752 | Tap:0.18085927922251796
# Epochs: 887: Nøyaktighet:0.752 | Tap:0.18085927914641656
# Epochs: 888: Nøyaktighet:0.752 | Tap:0.18085927907182814
# Epochs: 889: Nøyaktighet:0.752 | Tap:0.18085927899872264
# Epochs: 890: Nøyaktighet:0.752 | Tap:0.18085927892707065
# Epochs: 891: Nøyaktighet:0.752 | Tap:0.18085927885684314
# Epochs: 892: Nøyaktighet:0.752 | Tap:0.1808592787880119
# Epochs: 893: Nøyaktighet:0.752 | Tap:0.18085927872054908
# Epochs: 894: Nøyaktighet:0.752 | Tap:0.18085927865442755
# Epochs: 895: Nøyaktighet:0.752 | Tap:0.18085927858962061
# Epochs: 896: Nøyaktighet:0.752 | Tap:0.1808592785261021
# Epochs: 897: Nøyaktighet:0.752 | Tap:0.18085927846384647
# Epochs: 898: Nøyaktighet:0.752 | Tap:0.1808592784028285
# Epochs: 899: Nøyaktighet:0.752 | Tap:0.18085927834302368
# Epochs: 900: Nøyaktighet:0.752 | Tap:0.18085927828440787
# Epochs: 901: Nøyaktighet:0.752 | Tap:0.18085927822695744
# Epochs: 902: Nøyaktighet:0.752 | Tap:0.1808592781706492
# Epochs: 903: Nøyaktighet:0.752 | Tap:0.18085927811546038
# Epochs: 904: Nøyaktighet:0.752 | Tap:0.18085927806136884
# Epochs: 905: Nøyaktighet:0.752 | Tap:0.1808592780083527
# Epochs: 906: Nøyaktighet:0.752 | Tap:0.1808592779563906
# Epochs: 907: Nøyaktighet:0.752 | Tap:0.18085927790546155
# Epochs: 908: Nøyaktighet:0.752 | Tap:0.18085927785554504
# Epochs: 909: Nøyaktighet:0.752 | Tap:0.18085927780662092
# Epochs: 910: Nøyaktighet:0.752 | Tap:0.18085927775866947
# Epochs: 911: Nøyaktighet:0.752 | Tap:0.18085927771167137
# Epochs: 912: Nøyaktighet:0.752 | Tap:0.18085927766560767
# Epochs: 913: Nøyaktighet:0.752 | Tap:0.18085927762045975
# Epochs: 914: Nøyaktighet:0.752 | Tap:0.1808592775762094
# Epochs: 915: Nøyaktighet:0.752 | Tap:0.1808592775328388
# Epochs: 916: Nøyaktighet:0.752 | Tap:0.1808592774903305
# Epochs: 917: Nøyaktighet:0.752 | Tap:0.18085927744866728
# Epochs: 918: Nøyaktighet:0.752 | Tap:0.1808592774078324
# Epochs: 919: Nøyaktighet:0.752 | Tap:0.18085927736780935
# Epochs: 920: Nøyaktighet:0.752 | Tap:0.18085927732858198
# Epochs: 921: Nøyaktighet:0.752 | Tap:0.1808592772901345
# Epochs: 922: Nøyaktighet:0.752 | Tap:0.18085927725245143
# Epochs: 923: Nøyaktighet:0.752 | Tap:0.1808592772155175
# Epochs: 924: Nøyaktighet:0.752 | Tap:0.1808592771793179
# Epochs: 925: Nøyaktighet:0.752 | Tap:0.18085927714383795
# Epochs: 926: Nøyaktighet:0.752 | Tap:0.18085927710906338
# Epochs: 927: Nøyaktighet:0.752 | Tap:0.18085927707498015
# Epochs: 928: Nøyaktighet:0.752 | Tap:0.18085927704157456
# Epochs: 929: Nøyaktighet:0.752 | Tap:0.18085927700883309
# Epochs: 930: Nøyaktighet:0.752 | Tap:0.18085927697674253
# Epochs: 931: Nøyaktighet:0.752 | Tap:0.18085927694529003
# Epochs: 932: Nøyaktighet:0.752 | Tap:0.18085927691446277
# Epochs: 933: Nøyaktighet:0.752 | Tap:0.18085927688424844
# Epochs: 934: Nøyaktighet:0.752 | Tap:0.18085927685463474
# Epochs: 935: Nøyaktighet:0.752 | Tap:0.18085927682560982
# Epochs: 936: Nøyaktighet:0.752 | Tap:0.18085927679716193
# Epochs: 937: Nøyaktighet:0.752 | Tap:0.18085927676927963
# Epochs: 938: Nøyaktighet:0.752 | Tap:0.18085927674195165
# Epochs: 939: Nøyaktighet:0.752 | Tap:0.18085927671516694
# Epochs: 940: Nøyaktighet:0.752 | Tap:0.18085927668891477
# Epochs: 941: Nøyaktighet:0.752 | Tap:0.1808592766631845
# Epochs: 942: Nøyaktighet:0.752 | Tap:0.18085927663796578
# Epochs: 943: Nøyaktighet:0.752 | Tap:0.1808592766132484
# Epochs: 944: Nøyaktighet:0.752 | Tap:0.18085927658902246
# Epochs: 945: Nøyaktighet:0.752 | Tap:0.18085927656527812
# Epochs: 946: Nøyaktighet:0.752 | Tap:0.18085927654200584
# Epochs: 947: Nøyaktighet:0.752 | Tap:0.18085927651919625
# Epochs: 948: Nøyaktighet:0.752 | Tap:0.18085927649684014
# Epochs: 949: Nøyaktighet:0.752 | Tap:0.18085927647492844
# Epochs: 950: Nøyaktighet:0.752 | Tap:0.1808592764534524
# Epochs: 951: Nøyaktighet:0.752 | Tap:0.18085927643240327
# Epochs: 952: Nøyaktighet:0.752 | Tap:0.18085927641177266
# Epochs: 953: Nøyaktighet:0.752 | Tap:0.1808592763915522
# Epochs: 954: Nøyaktighet:0.752 | Tap:0.18085927637173374
# Epochs: 955: Nøyaktighet:0.752 | Tap:0.18085927635230928
# Epochs: 956: Nøyaktighet:0.752 | Tap:0.18085927633327098
# Epochs: 957: Nøyaktighet:0.752 | Tap:0.18085927631461116
# Epochs: 958: Nøyaktighet:0.752 | Tap:0.1808592762963223
# Epochs: 959: Nøyaktighet:0.752 | Tap:0.18085927627839707
# Epochs: 960: Nøyaktighet:0.752 | Tap:0.1808592762608282
# Epochs: 961: Nøyaktighet:0.752 | Tap:0.18085927624360856
# Epochs: 962: Nøyaktighet:0.752 | Tap:0.18085927622673134
# Epochs: 963: Nøyaktighet:0.752 | Tap:0.1808592762101896
# Epochs: 964: Nøyaktighet:0.752 | Tap:0.1808592761939767
# Epochs: 965: Nøyaktighet:0.752 | Tap:0.18085927617808617
# Epochs: 966: Nøyaktighet:0.752 | Tap:0.18085927616251155
# Epochs: 967: Nøyaktighet:0.752 | Tap:0.18085927614724653
# Epochs: 968: Nøyaktighet:0.752 | Tap:0.180859276132285
# Epochs: 969: Nøyaktighet:0.752 | Tap:0.18085927611762087
# Epochs: 970: Nøyaktighet:0.752 | Tap:0.1808592761032483
# Epochs: 971: Nøyaktighet:0.752 | Tap:0.18085927608916147
# Epochs: 972: Nøyaktighet:0.752 | Tap:0.18085927607535474
# Epochs: 973: Nøyaktighet:0.752 | Tap:0.18085927606182242
# Epochs: 974: Nøyaktighet:0.752 | Tap:0.18085927604855917
# Epochs: 975: Nøyaktighet:0.752 | Tap:0.1808592760355596
# Epochs: 976: Nøyaktighet:0.752 | Tap:0.18085927602281845
# Epochs: 977: Nøyaktighet:0.752 | Tap:0.18085927601033058
# Epochs: 978: Nøyaktighet:0.752 | Tap:0.18085927599809098
# Epochs: 979: Nøyaktighet:0.752 | Tap:0.18085927598609475
# Epochs: 980: Nøyaktighet:0.752 | Tap:0.18085927597433699
# Epochs: 981: Nøyaktighet:0.752 | Tap:0.18085927596281295
# Epochs: 982: Nøyaktighet:0.752 | Tap:0.18085927595151804
# Epochs: 983: Nøyaktighet:0.752 | Tap:0.18085927594044768
# Epochs: 984: Nøyaktighet:0.752 | Tap:0.18085927592959736
# Epochs: 985: Nøyaktighet:0.752 | Tap:0.18085927591896278
# Epochs: 986: Nøyaktighet:0.752 | Tap:0.18085927590853962
# Epochs: 987: Nøyaktighet:0.752 | Tap:0.18085927589832368
# Epochs: 988: Nøyaktighet:0.752 | Tap:0.18085927588831083
# Epochs: 989: Nøyaktighet:0.753 | Tap:0.180859275878497
# Epochs: 990: Nøyaktighet:0.753 | Tap:0.18085927586887834
# Epochs: 991: Nøyaktighet:0.753 | Tap:0.18085927585945086
# Epochs: 992: Nøyaktighet:0.753 | Tap:0.1808592758502108
# Epochs: 993: Nøyaktighet:0.753 | Tap:0.18085927584115444
# Epochs: 994: Nøyaktighet:0.753 | Tap:0.18085927583227815
# Epochs: 995: Nøyaktighet:0.753 | Tap:0.18085927582357827
# Epochs: 996: Nøyaktighet:0.753 | Tap:0.18085927581505137
# Epochs: 997: Nøyaktighet:0.753 | Tap:0.18085927580669398
# Epochs: 998: Nøyaktighet:0.753 | Tap:0.18085927579850275
# Epochs: 999: Nøyaktighet:0.753 | Tap:0.18085927579047437

# %% [markdown]
# ### Task: Scaling

# %% [markdown]
# we have seen in the lectures that scaling the data may improve training speed.
#
# - Implement a scaler, either standard scaler (normalizer) or max-min scaler
# - Scale the data
# - Train the model on the scaled data
# - Experiment with hyper-parameter settings and see whether you can speed  up  the training.
# - Report final hyper-meter settings and show how you found them.
# - Plot the loss curve and the accuracy curve for the classifier trained on scaled data with the best settings you found.

# %% [markdown]
# ## Logistic regression
# a) You should now implement a logistic regression classifier similarly to the classifier based on linear regression.
# You may use code from the solution to weekly exercise set week07.
#
# b) In addition to the method `predict` which predicts a class for the data, include a method `predict_probability` which predicts the probability of the data belonging to the positive class.
#
# c) As with the classifier based on linear regression, we want to calculate loss and accuracy after each epoch.
# The prefered loss for logistic regression is binary cross-entropy. You could have used mean squared error. The most important is that your implementation of the loss corresponds to your implementation of the gradient descent.
#
# d) In addition, extend the fit-method with optional arguments for a validation set (X_val, t_val). If a validation set is included in the call to fit, calculate the loss and the accuracy for the validation set after each epoch.
#
# e) The training runs for a number of epochs. We cannot know beforehand for how many epochs it is reasonable to run the training. One possibility is to run the training until the learning does not improve much. Extend the fit-method with two keyword arguments, `tol` and `n_epochs_no_update` and stop training when the loss has not improved with more than `tol` after running `n_epochs_no_update` epochs. A possible default value for `n_epochs_no_update` is 5. Also, add an attribute to the classifier which tells us after fitting how many epochs were ran.
#
# f) Train classifiers with various learning rates, and with varying values for `tol` for finding optimal values. Also consider the effect of scaling the data.
#
# g) After a succesful training, plot both training loss and validation loss as functions of the number of epochs in one figure, and both accuracies as functions of the number of epochs in another figure. Comment on what you see.

# %%
def sigmoid(x):
    return 1/(1+np.exp(-x))

def cel(y, y_pred):
    sum_errors = 0.
    for i in range(0,len(y)):
        if y[i] == 1:
            sum_errors -= np.log(sigmoid(y_pred[i]))
        else: 
            sum_errors -= np.log(1-sigmoid(y_pred[i]))
    
    cross_entropy_error = sum_errors/len(y)
    return cross_entropy_error

class NumpyLogReg(NumpyClassifier):

    def __init__(self, bias=-1):
        self.bias = bias

    def fit(self, X_train, t_train, X_val, t_val, eta = 0.01, epochs=1000, tol=1e-4):
        diff = 1
        # antall_epochs = 0
        losses     = []
        accuracy   = []
        losses_v   = []
        accuracy_v = []
        
        (k, m) = X_train.shape
        X_traino = X_train
        X_train = add_bias(X_train, self.bias)
        X_valo = X_val
        X_val = add_bias(X_val, self.bias)
        
        self.weights = weights = np.zeros(m+1)        
        while diff > tol:
           
            oldError = cel(t_train, X_train@weights)
            weights -= eta / k *  X_train.T @ (self.predict_probability(X_train) - t_train) 
            newError = cel(t_train, X_train@weights)
            diff = oldError - newError
            
            mse = cel(t_train, X_train @ weights)
            losses.append(mse)
             
            aq = self.accuracy(X_traino, t2_train)
            accuracy.append(aq)
            
            # oldError_v = cel(t_val, X_val @ weights)
            # newError_v = cel(t_val, X_val @ weights)
            
            mse_v = cel(t_val, X_val @ weights)
            losses_v.append(mse_v)
            
            aq_v = self.accuracy(X_valo, t2_val)
            accuracy_v.append(aq_v)
            
            # antall_epochs +=1

             
        return losses, accuracy, losses_v, accuracy_v

    
    def predict_probability(self, X):
        return sigmoid(X @ self.weights)
    
    def score(self, x):
        z = add_bias(x, self.bias)
        score = self.predict_probability(z)
        return score
    
    def predict(self, x, threshold=0.5):
        z = add_bias(x, self.bias)
        score = self.predict_probability(z)
        return (score>threshold).astype('int')
    
    
    def accuracy(self,X_test, y_test, **kwargs):
        pred = self.predict(X_test, **kwargs)
        if len(pred.shape) > 1:
            pred = pred[:,0]
        return np.sum(pred==y_test)/len(pred)
    

log_cl = NumpyLogReg()
log_cl.fit(X_train, t2_train, X_val, t2_val)
log_cl.accuracy(X_val, t2_val)

losses, accuracy, losses2, accuracy2 = log_cl.fit(X_train, t2_train, X_val, t2_val)
plt.plot(accuracy)
plt.plot(accuracy2)
plt.xlabel('epoches')
plt.title('accuracy')
plt.show()

plt.plot(losses)
plt.plot(losses2)
plt.xlabel('epoches')
plt.title('lossess')
plt.show()

# %% [markdown]
# ## Multi-class classifiers
# We turn to the task of classifying when there are more than two classes, and the task is to ascribe one class to each input. We will now use the set (X, t_multi).

# %% [markdown]
# ### "One-vs-rest" with logistic regression
# We saw in the lecture how a logistic regression classifier can be turned into a multi-class classifier using the one-vs-rest approach. We train one logistic regression classifier for each class. To predict the class of an item, we run all the binary classifiers and collect the probability score from each of them. We assign the class which ascribes the highest probability.
#
# Build such a classifier. Train the resulting classifier on (X_train, t_multi_train), test it on (X_val, t_multi_val), tune the hyper-parameters and report the accuracy.
#
# Also plot the decision boundaries for your best classifier similarly to the plots for the binary case.

# %% [markdown]
# ### For in4050-students: Multi-nominal logistic regression
# The following part is only mandatory for in4050-students. In3050-students are also welcome to make it a try. Everybody has to return for the part 2 on multi-layer neural networks.
#
# In the lecture, we contrasted the one-vs-rest approach with the multinomial logistic regression, also called softmax classifier. Implement also this classifier, tune the parameters, and compare the results to the one-vs-rest classifier.
#
# Remember that this classifier uses softmax in the forward phase. For loss, it uses categorical cross-entropy loss. The loss has a somewhat simpler form than in the binary case. To calculate the gradient is a little more complicated. The actual gradient and update rule is simple, however, as long as you have calculated the forward values correctly.

# %% [markdown]
# # Part II Multi-layer neural networks

# %% [markdown]
# ## A first non-linear classifier

# %% [markdown]
# The following code it a simple implementation of a multi-layer perceptron.
# It is quite restricted.
# There is only one hidden layer.
# It can only handle binary classification.
# In addition, it uses a simple final layer similar to the linear regression classifier above.
# One way to look at it is what happens when we add a hidden layer to the linear regression classifier.
#
# It can be used to make a non-linear classifier for the set (X, t2).
# Experiment with settings for learning rate and epochs and see how good results you can get.
# Report results for variouse settings.
# Be prepared to train for a looooong time.
# Plot the training set together with the decision regions as in part I.

# %%
class MLPBinaryLinRegClass(NumpyClassifier):
    """A multi-layer neural network with one hidden layer"""
    
    def __init__(self, bias=-1, dim_hidden = 6):
        """Intialize the hyperparameters"""
        self.bias = bias
        self.dim_hidden = dim_hidden
        
        def logistic(x):
            return 1/(1+np.exp(-x))
        self.activ = logistic
        
        def logistic_diff(y):
            return y * (1 - y)
        self.activ_diff = logistic_diff
        
    def fit(self, X_train, t_train, eta=0.001, epochs = 100):
        """Intialize the weights. Train *epochs* many epochs.
        
        X_train is a Nxm matrix, N data points, m features
        t_train is a vector of length N of targets values for the training data, 
        where the values are 0 or 1.
        """
        self.eta = eta
        
        T_train = t_train.reshape(-1,1)
            
        dim_in = X_train.shape[1] 
        dim_out = T_train.shape[1]
        
        # Itilaize the wights
        self.weights1 = (np.random.rand(
            dim_in + 1, 
            self.dim_hidden) * 2 - 1)/np.sqrt(dim_in)
        self.weights2 = (np.random.rand(
            self.dim_hidden+1, 
            dim_out) * 2 - 1)/np.sqrt(self.dim_hidden)
        X_train_bias = add_bias(X_train, self.bias)
        
        for e in range(epochs):
            # One epoch
            hidden_outs, outputs = self.forward(X_train_bias)
            # The forward step
            out_deltas = (outputs - T_train)
            # The delta term on the output node
            hiddenout_diffs = out_deltas @ self.weights2.T
            # The delta terms at the output of the jidden layer
            hiddenact_deltas = (hiddenout_diffs[:, 1:] * 
                                self.activ_diff(hidden_outs[:, 1:]))  
            # The deltas at the input to the hidden layer
            self.weights2 -= self.eta * hidden_outs.T @ out_deltas
            self.weights1 -= self.eta * X_train_bias.T @ hiddenact_deltas 
            # Update the weights
            
    def forward(self, X):
        """Perform one forward step. 
        Return a pair consisting of the outputs of the hidden_layer
        and the outputs on the final layer"""
        hidden_activations = self.activ(X @ self.weights1)
        hidden_outs = add_bias(hidden_activations, self.bias)
        outputs = hidden_outs @ self.weights2
        return hidden_outs, outputs
    
    def predict(self, X):
        """Predict the class for the mebers of X"""
        Z = add_bias(X, self.bias)
        forw = self.forward(Z)[1]
        score= forw[:, 0]
        return (score > 0.5)

# %% [markdown]
# ## Improving the classifier
# You should now make changes to the classifier similarly to what you did with the logistic regression classifier in part 1.
#
# a) In addition to the method predict, which predicts a class for the data, include a method predict_probability which predict the probability of the data belonging to the positive class. The training should be based on this value as with logistic regression.
#
# b) Calculate the loss and the accuracy after each epoch and store them for inspection after training.
#
# c) In addition, extend the fit-method with optional arguments for a validation set (X_val, t_val). If a validation set is included in the call to fit, calculate the loss and the accuracy for the validation set after each epoch.
#
# d) The training runs for a number of epochs. We cannot know beforehand for how many epochs it is reasonable to run the training. One possibility is to run the training until the learning does not improve much. Extend the fit method with two keyword arguments, `tol` and `n_epochs_no_update` and stop training when the loss has not improved with more than tol after `n_epochs_no_update`. A possible default value for `n_epochs_no_update` is 5. Also, add an attribute to the classifier which tells us after fitting how many epochs were ran.
#
# e) Tune the hyper-parameters:`eta`, `tol`and `dim-hidden`.
# Also consider the effect of scaling the data.
#
# f) After a succesful training with a best setting for the hyper-parameters, plot both training loss and validation loss as functions of the number of epochs in one figure, and both accuracies as functions of the number of epochs in another figure. Comment on what you see.
#
# g) The algorithm contains an element of non-determinism. Hence, train the classifier 10 times with the optimal hyper-parameters and report the mean and standard deviation of the accuracies over the 10 runs.

# %% [markdown]
# ## For IN4050-students: Multi-class neural network

# %% [markdown]
# The following part is only mandatory for in4050-students. In3050-students are also welcome to make it a try. (This is the most fun part of the set :) )
#
# The goal is to use a feed-forward network for non-linear multi-class classfication and apply it to set (X, t_multi).
#
# Modify the netork to become a multi-class classifier. As a check of your implementation, you may apply it to (X, t_2) and see whether you get similar results as above.
#
# Train the resulting classifier on (X_train, t_multi_train), test it on (X_val, t_multi_val), tune the hyper-parameters and report the accuracy.
#
# Plot the decision boundaries for your best classifier..

# %% [markdown]
# # Part III: Final testing
# We can now perform a final testing on the held-out test set.
#
# ## Binary task (X, t2)
# Consider the linear regression classifier, the logistic regression classifier and the multi-layer network with the best settings you found. Train each of them on the training set and calculate accuracy on the held-out test set, but also on the validation set and the training set. Report in a 3 by 3 table.
#
# Comment on what you see. How do the three different algorithms compare? Also, compare the results between the different data sets. In cases like these, one might expect slightly inferior results on the held-out test data compared to the validation data. Is that the case here?
#
# Also report precision and recall for class 1.
#
# ## For IN4050-students: Multi-class task (X, t_multi)
# The following part is only mandatory for in4050-students. In3050-students are also welcome to do it. It requires the earlier IN4050-only tasks.
#
# Compare the three multi-class classfiers, the one-vs-rest and the multinomial logistic regression from part one, and the multi-class neural network from part two. Evaluate on test, validation and training set as above.
#
# Comment on what you see
